# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - HamLib Simulation - Plot Observables Metrics
#
# The notebook contains specific examples for the HamLib-based Hamiltonian Simulation benchmark program.
# Configure and run the cell below with the desired execution settings.
# Then configure and run the remaining cell(s), each one producing a plot illustrating benchmark results.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# Settings used when generating the datasets.
max_circuits =1
num_shots = 10000

K = 1             # number of Trotter steps
t = 0.1           # total evolution time

#backend_id="qasm_simulator"
backend_id="statevector_simulator"

api = "qiskit"

# %%
# Initialize QED-C framework
import sys
sys.path.insert(1, "..")

from qedclib import initialize, metrics
initialize("qiskit", "hamlib", ["hamlib_simulation_kernel"])

# Configure benchmark library modules
import hamlib_simulation_benchmark
from hamlib._common import metric_plots
# Out:
# ... qedclib 2.0.5

# %% [markdown]
# ### List of Available Hamiltonians
# For the plotting illustrate below, select one of the available Hamiltonian name, params tuples.
# In the cells at the end of the notebook, we loop over all the Hamiltonians.

# %%
# List of HamLib filename and parameter tuples
hamiltonians = [
    ('condensedmatter/tfim/tfim', { "1D-grid": "pbc", "h": 2 }),
    ('condensedmatter/heisenberg/heis', { "1D-grid": "pbc", "h": 2 }),
    ('condensedmatter/fermihubbard/FH_D-1', { "1D-grid": "pbc", "enc": "bk", "U":12 }),
    ('condensedmatter/bosehubbard/BH_D-1_d-4', { "1D-grid": "nonpbc", "enc": "gray", "U":10 }),
    ('binaryoptimization/max3sat/random/random_max3sat-hams', { "ratio": "2", "rinst": "02" }),
    ('chemistry/electronic/standard/H2', { "ham_BK": "" })
    ]

# Select one of the Hamiltonians
hamiltonian_name, hamiltonian_params = hamiltonians[ 1 ]

# %% [markdown]
# ### Load Metrics Data File for a Specific Hamiltonian
# Here we define a function to load the Hamiltonian benchmark data file and extract the metrics of interest.

# %%
def get_data_for_app_backend_group(app_name: str, backend_id: str, group_method: str):
    metrics_array = hamlib_simulation_benchmark.load_app_metrics(app_name, backend_id)

    data = hamlib_simulation_benchmark.query_dict_array(metrics_array, dict(group_method=group_method))

    # pull groups list from the "nvidia" dataset which is the largest
    groups = [m["group"] for m in data]
    
    exp_values_computed = [m["exp_value_computed"] for m in data]
    exp_times_computed = [m["exp_time_computed"] for m in data]

    # move these to their own dataset, instead of being part of computed data
    # pull exact values and times from the dataset; remove null values
    exp_values_exact = [m["exp_value_exact"] for m in data]
    exp_values_exact = [x for x in exp_values_exact if x is not None]
    exp_times_exact = [m["exp_time_exact"] for m in data]
    exp_times_exact = [x for x in exp_times_exact if x is not None]

    return groups, exp_values_computed, exp_times_computed, exp_values_exact, exp_times_exact

# %% [markdown]
# ### Regenerate HamLib Benchmark Standard Plot
# Here we invoke the same function that the benchmark uses to generate its plot.  We pass in the metrics of interest.

# %%
#### expectation value and time plots

# Construct benchmark data file name and load the metrics 
app_name = f"HamLib-obs-{hamiltonian_name}"

metrics_array = hamlib_simulation_benchmark.load_app_metrics(app_name, backend_id)

# pull for statevector_simulator backend

#data_simple = hamlib_simulation_benchmark.query_dict_array(metrics_array, dict(group_method="simple"))
data_N = hamlib_simulation_benchmark.query_dict_array(metrics_array, dict(group_method="N"))

benchmark_name = "HamLib Simulation"

options = {"ham": hamiltonian_name.replace("/", "_"), "params": hamiltonian_params,
                "method": 4, "gm": "?", "K": 0, "t": 0.1, "shots": num_shots, "reps": max_circuits } 

suptitle = f"Benchmark Results - {benchmark_name} - Expectation"

hamlib_simulation_benchmark.plot_from_data(suptitle, data_N, backend_id, options)
# Out:
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_heisenberg_heis.json
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Regenerate the Plots using Plot Functions
# This example uses functions from the metric_plots module.

# %%
#### expectation value and time plots, using individual functions
benchmark_name = "HamLib Simulation"

groups_simple, exp_values_simple, exp_times_simple, exp_values_exact, exp_times_exact = \
        get_data_for_app_backend_group(app_name, backend_id, "simple")

options = {"ham": hamiltonian_name.replace("/", "_"), "params": hamiltonian_params,
                "method": 4, "gm": "?", "K": 0, "t": 0.1, "shots": num_shots, "reps": max_circuits } 

suptitle = f"Benchmark Results - {benchmark_name} - Expectation"

# plot all line metrics, including solution quality and accuracy ratio
# vs iteration count and cumulative execution time
metric_plots.plot_expectation_value_metrics(
    suptitle,
    backend_id=backend_id,
    options=options,
    
    groups=groups_simple,
    expectation_values_exact=exp_values_exact,
    expectation_values_computed=exp_values_simple,   
)

# expectation time plot
# plot all line metrics, including solution quality and accuracy ratio
# vs iteration count and cumulative execution time
metric_plots.plot_expectation_time_metrics(
    suptitle,
    backend_id=backend_id,
    options=options,
    
    groups=groups_simple,
    expectation_times_exact=exp_times_exact,
    expectation_times_computed=exp_times_simple,
)
# Out:
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_heisenberg_heis.json
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Produce Multiple Plots from Multiple Datasets
# Here, we combine data from several sources.  (so far, we pull all data from a single data file, but this will be enhanced)

# %%
# Select a backend on which the benchmark was executed
backend_id="statevector_simulator"
#backend_id="qasm_simulator"
backend_id_nvidia = "nvidia"
backend_id_ibm = "ibm_sherbrooke"

# metrics already imported from qedclib above
metrics.data_suffix = ""
hamlib_simulation_benchmark.data_suffix = ""

######## for paper ...
"""
# place resulting data and images into a folder with "paper" suffix
backend_id="statevector_simulator"
metrics.data_suffix = "_paper"
hamlib_simulation_benchmark.data_suffix = "_paper"
"""
#########

ham_indexes = range(len(hamiltonians))
#ham_indexes = [2,3]       # select subset for example

for i in ham_indexes:
    
    hamiltonian_name, hamiltonian_params = hamiltonians[ i ]
    print(f"\n*******************************************************************************************")
    print(f"\nHamiltonian = {hamiltonian_name} : Parameters = {hamiltonian_params}\n")
    
    # Construct benchmark data file name and load the metrics 
    app_name = f"HamLib-obs-{hamiltonian_name}"
       
    #####################################################
    # pull for statevector_simulator and nvidia backends 
    
    groups_simple, exp_values_simple, exp_times_simple, exp_values_exact, exp_times_exact = \
            get_data_for_app_backend_group(app_name, backend_id, "simple")
    
    groups_none, exp_values_none, exp_times_none, _, _ = \
            get_data_for_app_backend_group(app_name, backend_id, None)
    
    groups_N, exp_values_N, exp_times_N, _, _ = \
            get_data_for_app_backend_group(app_name, backend_id, "N")
    
    groups_est, exp_values_est, exp_times_est, _, _ = \
            get_data_for_app_backend_group(app_name, backend_id, "estimator")
    
    groups_nvidia, exp_values_nvidia, exp_times_nvidia, _, _ = \
            get_data_for_app_backend_group(app_name, backend_id_nvidia, None)

    groups_noisy, exp_values_noisy, exp_times_noisy, _, _ = \
            get_data_for_app_backend_group(app_name, "qasm_simulator_noisy", "simple")

    groups_ibm, exp_values_ibm, exp_times_ibm, _, _ = \
            get_data_for_app_backend_group(app_name, backend_id_ibm, "simple")

    # suppress for now
    #groups_ibm = exp_values_ibm = exp_times_ibm = []
    
    # include both statevector and nvidia data in the plot
    labels = [ "Exact", "No Groups", "Simple Groups", "N-Qubit Groups", "Estimator", "NVIDIA", "Noisy Sim", "Sherbrooke" ]
    groups = [ groups_simple, groups_none, groups_simple, groups_N, groups_est, groups_nvidia, groups_noisy, groups_ibm]
    values = [ exp_values_exact, exp_values_none, exp_values_simple, exp_values_N, exp_values_est, exp_values_nvidia, exp_values_noisy, exp_values_ibm]
    times = [ exp_times_exact, exp_times_none, exp_times_simple, exp_times_N, exp_times_est, exp_times_nvidia, exp_times_noisy, exp_times_ibm]
    
    #####################################################
    # create expectation value and time plots
    
    benchmark_name = "HamLib Simulation"
    options = { "ham": hamiltonian_name.replace("/", "_"), "gm": "?", "shots": "?", "reps": 1  }
    
    suptitle = f"Benchmark Results - {benchmark_name} - Expectation"
    suptitle += f"\nHamiltonian={hamiltonian_name}"
    #suptitle += f"\n{hamiltonian_params}"
    suptitle += f"\nDevice={backend_id}{(', ' + backend_id_nvidia) if backend_id_nvidia else ''}"
    suptitle += f", shots={num_shots}, reps={max_circuits}"
    
    # plot all line metrics, including solution quality and accuracy ratio
    # vs iteration count and cumulative execution time
    metric_plots.plot_expectation_value_metrics_2(
        suptitle,
        backend_id=backend_id,
        options=options,
        
        groups = groups,
        labels = labels,
        values = values  
    )
    
    # expectation time plot
    # plot all line metrics, including solution quality and accuracy ratio
    # vs iteration count and cumulative execution time
    metric_plots.plot_expectation_time_metrics_2(
        suptitle,
        backend_id=backend_id,
        options=options,
        
        groups = groups,
        labels = labels,
        times = times
    )
# Out:
# *******************************************************************************************
#
# Hamiltonian = condensedmatter/tfim/tfim : Parameters = {'1D-grid': 'pbc', 'h': 2}
#
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_tfim_tfim.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_tfim_tfim.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_tfim_tfim.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_tfim_tfim.json
# WARNING: cannot load metrics file: __data/qasm_simulator_noisy/HamLib-obs-condensedmatter_tfim_tfim.json
# WARNING: cannot load metrics file: __data/ibm_sherbrooke/HamLib-obs-condensedmatter_tfim_tfim.json
# ----- Expectation Value Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:601: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# ----- Expectation Time Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:818: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# *******************************************************************************************
#
# Hamiltonian = condensedmatter/heisenberg/heis : Parameters = {'1D-grid': 'pbc', 'h': 2}
#
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_heisenberg_heis.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_heisenberg_heis.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_heisenberg_heis.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_heisenberg_heis.json
# WARNING: cannot load metrics file: __data/qasm_simulator_noisy/HamLib-obs-condensedmatter_heisenberg_heis.json
# WARNING: cannot load metrics file: __data/ibm_sherbrooke/HamLib-obs-condensedmatter_heisenberg_heis.json
# ----- Expectation Value Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:601: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# ----- Expectation Time Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:818: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# *******************************************************************************************
#
# Hamiltonian = condensedmatter/fermihubbard/FH_D-1 : Parameters = {'1D-grid': 'pbc', 'enc': 'bk', 'U': 12}
#
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_fermihubbard_FH_D-1.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_fermihubbard_FH_D-1.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_fermihubbard_FH_D-1.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_fermihubbard_FH_D-1.json
# WARNING: cannot load metrics file: __data/qasm_simulator_noisy/HamLib-obs-condensedmatter_fermihubbard_FH_D-1.json
# WARNING: cannot load metrics file: __data/ibm_sherbrooke/HamLib-obs-condensedmatter_fermihubbard_FH_D-1.json
# ----- Expectation Value Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:601: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# ----- Expectation Time Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:818: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# *******************************************************************************************
#
# Hamiltonian = condensedmatter/bosehubbard/BH_D-1_d-4 : Parameters = {'1D-grid': 'nonpbc', 'enc': 'gray', 'U': 10}
#
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_bosehubbard_BH_D-1_d-4.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_bosehubbard_BH_D-1_d-4.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_bosehubbard_BH_D-1_d-4.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-condensedmatter_bosehubbard_BH_D-1_d-4.json
# WARNING: cannot load metrics file: __data/qasm_simulator_noisy/HamLib-obs-condensedmatter_bosehubbard_BH_D-1_d-4.json
# WARNING: cannot load metrics file: __data/ibm_sherbrooke/HamLib-obs-condensedmatter_bosehubbard_BH_D-1_d-4.json
# ----- Expectation Value Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:601: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# ----- Expectation Time Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:818: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# *******************************************************************************************
#
# Hamiltonian = binaryoptimization/max3sat/random/random_max3sat-hams : Parameters = {'ratio': '2', 'rinst': '02'}
#
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-binaryoptimization_max3sat_random_random_max3sat-hams.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-binaryoptimization_max3sat_random_random_max3sat-hams.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-binaryoptimization_max3sat_random_random_max3sat-hams.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-binaryoptimization_max3sat_random_random_max3sat-hams.json
# WARNING: cannot load metrics file: __data/qasm_simulator_noisy/HamLib-obs-binaryoptimization_max3sat_random_random_max3sat-hams.json
# WARNING: cannot load metrics file: __data/ibm_sherbrooke/HamLib-obs-binaryoptimization_max3sat_random_random_max3sat-hams.json
# ----- Expectation Value Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:601: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# ----- Expectation Time Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:818: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# *******************************************************************************************
#
# Hamiltonian = chemistry/electronic/standard/H2 : Parameters = {'ham_BK': ''}
#
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-chemistry_electronic_standard_H2.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-chemistry_electronic_standard_H2.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-chemistry_electronic_standard_H2.json
# WARNING: cannot load metrics file: __data/statevector_simulator/HamLib-obs-chemistry_electronic_standard_H2.json
# WARNING: cannot load metrics file: __data/qasm_simulator_noisy/HamLib-obs-chemistry_electronic_standard_H2.json
# WARNING: cannot load metrics file: __data/ibm_sherbrooke/HamLib-obs-chemistry_electronic_standard_H2.json
# ----- Expectation Value Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:601: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# ----- Expectation Time Plot -----
# C:\Dropbox\Common\github-tl\qcwork\apps\QC-App-Oriented-Benchmarks-master\qedcbench\hamlib\_common\metric_plots.py:818: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
