# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Hamiltonian Simulation with HamLib - Observables - CUDA Quantum
#
# The notebook contains specific examples for the HamLib-based Hamiltonian Simulation benchmark program.
#
# This benchmark executes a Hamiltonian simulation using the Hamiltonian terms extracted from the specified HamLib dataset.
# It computes observable values for the selected Hamiltonian, and plots the expectation value and execution time over the number of qubits in the problem.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Application and Execution Settings
# Configure and run the cell below with the desired execution settings. Then configure and run the remaining cell(s), each one a variation of this benchmark.

# %%
# Benchmark application settings
app_args = dict(
    min_qubits = 4,
    max_qubits = 24,
    skip_qubits = 1,
    max_circuits = 1,
    
    # total shots allocation, by default evenly divided among all executions at one qubit size
    num_shots = 10000,

    # this notebook executes observable benchmarks
    method = 4,
    do_observables = True,
    
    # execute by distributing num_shots weighted by term coefficients (N/A for cudaq)
    distribute_shots = False,
    
    # number of Trotter steps and total evolution time
    K = 1,
    t = 0.1,
    
    # initial state can be "checkerboard", "ghz", or bitstring of 0s and 1s
    init_state = "checkerboard",

    # "SpinOperator" is the default option for CUDA Q
    # None or "simple" can be slow for K > 0
    group_method = "SpinOperator",    # method to generate commuting groups
                                      # None, "simple", or "SpinOperator"
     
    # which API to use for execution, "qiskit" or "cudaq"
    api = "cudaq",
)

# Default execution settings
exec_args = dict(
    hub="", group="", project="",
    provider_backend = None,
    
    backend_id="nvidia",

    exec_options = {},
)

# %% [markdown]
# ### Imports for Debugging Options
# These may be removed later, but during development they are convenient.

# %%
# Initialize QED-C framework (loads API-specific modules)
# The imports below provide direct access to internal modules for debugging and tracing
import sys
sys.path.insert(1, "..")

from qedclib import initialize, metrics
initialize("cudaq", "hamlib", ["hamlib_simulation_kernel"])

import execute
execute.verbose = False
execute.verbose_time = False

# ... access to HamLib datasets
import hamlib._common.hamlib_utils as hamlib_utils
hamlib_utils.verbose = False

# ... for api-specific kernel functions (circuits)
import hamlib_simulation_kernel
hamlib_simulation_kernel.verbose = False

# ... for high-level HamLib simulation benchmark loop
import hamlib_simulation_benchmark
hamlib_simulation_benchmark.verbose = False

#####################
# use re-ordered list from Spin Operator for Trotter circuit creation (default = True)
hamlib_simulation_kernel.use_commuting_terms = True

#metrics.data_suffix = "_paper"
#hamlib_simulation_benchmark.data_suffix = "_paper"

# control the max number of qubits for which to compute exact answer
hamlib_simulation_benchmark.max_qubits_exact = 16
# Out:
# QED-C Quantum Circuit Execution Library (qedclib 2.0.6)

# %% [markdown]
# ### Hamiltonian Simulation - Transverse Field Ising Model

# %%
# Transverse Field Ising Model - 1D grid pbc h=2
hamiltonian_name = 'condensedmatter/tfim/tfim'
hamiltonian_params = { "1D-grid": "pbc", "h": 2 }

hamlib_simulation_benchmark.run(
            hamiltonian=hamiltonian_name, hamiltonian_params=hamiltonian_params,
            **app_args, **exec_args)
# Out:
# WARNING: Qiskit-dependent exact evolution functions are not available
# WARNING: Qiskit-dependent compute observable value functions are not available.
# Hamiltonian Simulation Benchmark Program - cudaq
# ... hamiltonian and params = condensedmatter/tfim/tfim, {'1D-grid': 'pbc', 'h': 2}
# ... group_method = SpinOperator
# ... execution starting at Jun 14, 2026 23:21:21 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 4
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-4_h-2
# ... number of terms in Hamiltonian = 8
# ... total elapsed execution time = 0.187
# ... exact computation time = 0.006 sec
#
#     Exact expectation value, computed classically: -4.0
#     Estimated expectation value, from quantum algorithm: -4.3934
#     ==> Simulation Quality: 1.098
#
# ************
# Executing [1] circuits with num_qubits = 5
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-5_h-2
# ... number of terms in Hamiltonian = 10
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.007 sec
#
#     Exact expectation value, computed classically: -3.0
#     Estimated expectation value, from quantum algorithm: -3.5451
#     ==> Simulation Quality: 1.182
#
# ************
# Executing [1] circuits with num_qubits = 6
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-6_h-2
# ... number of terms in Hamiltonian = 12
# ... total elapsed execution time = 0.001
# ... exact computation time = 0.008 sec
#
#     Exact expectation value, computed classically: -6.0
#     Estimated expectation value, from quantum algorithm: -6.0901
#     ==> Simulation Quality: 1.015
#
# ************
# Executing [1] circuits with num_qubits = 7
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-7_h-2
# ... number of terms in Hamiltonian = 14
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.011 sec
#
#     Exact expectation value, computed classically: -5.0
#     Estimated expectation value, from quantum algorithm: -5.2418
#     ==> Simulation Quality: 1.048
#
# ************
# Executing [1] circuits with num_qubits = 8
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-8_h-2
# ... number of terms in Hamiltonian = 16
# ... total elapsed execution time = 0.002
# ... exact computation time = 0.015 sec
#
#     Exact expectation value, computed classically: -8.0
#     Estimated expectation value, from quantum algorithm: -7.7868
#     ==> Simulation Quality: 0.973
#
# ************
# Executing [1] circuits with num_qubits = 9
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-9_h-2
# ... number of terms in Hamiltonian = 18
# ... total elapsed execution time = 0.003
# ... exact computation time = 0.02 sec
#
#     Exact expectation value, computed classically: -7.0
#     Estimated expectation value, from quantum algorithm: -6.9385
#     ==> Simulation Quality: 0.991
#
# ************
# Executing [1] circuits with num_qubits = 10
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-10_h-2
# ... number of terms in Hamiltonian = 20
# ... total elapsed execution time = 0.002
# ... exact computation time = 0.025 sec
#
#     Exact expectation value, computed classically: -10.0
#     Estimated expectation value, from quantum algorithm: -9.4835
#     ==> Simulation Quality: 0.948
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-2
# ... number of terms in Hamiltonian = 24
# ... total elapsed execution time = 0.003
# ... exact computation time = 0.042 sec
#
#     Exact expectation value, computed classically: -12.0
#     Estimated expectation value, from quantum algorithm: -11.1802
#     ==> Simulation Quality: 0.932
#
# ************
# Executing [1] circuits with num_qubits = 14
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-14_h-2
# ... number of terms in Hamiltonian = 28
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.092 sec
#
#     Exact expectation value, computed classically: -14.0
#     Estimated expectation value, from quantum algorithm: -12.877
#     ==> Simulation Quality: 0.92
#
# ************
# Executing [1] circuits with num_qubits = 16
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-16_h-2
# ... number of terms in Hamiltonian = 32
# ... total elapsed execution time = 0.006
# ... exact computation time = 0.263 sec
#
#     Exact expectation value, computed classically: -16.0
#     Estimated expectation value, from quantum algorithm: -14.5737
#     ==> Simulation Quality: 0.911
#
# ************
# Executing [1] circuits with num_qubits = 18
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-18_h-2
# ... number of terms in Hamiltonian = 36
# ... total elapsed execution time = 0.005
#
#     Estimated expectation value, from quantum algorithm: -16.2704
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-20_h-2
# ... number of terms in Hamiltonian = 40
# ... total elapsed execution time = 0.006
#
#     Estimated expectation value, from quantum algorithm: -17.9671
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-22_h-2
# ... number of terms in Hamiltonian = 44
# ... total elapsed execution time = 0.008
#
#     Estimated expectation value, from quantum algorithm: -19.6638
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-24_h-2
# ... number of terms in Hamiltonian = 48
# ... total elapsed execution time = 0.036
#
#     Estimated expectation value, from quantum algorithm: -21.3605
#     ==> Simulation Quality: 0.0
#
# ... execution complete at Jun 14, 2026 23:21:22 UTC in 0.799 secs
#
# Sample Circuit:
# WARNING: cudaq cannot draw kernels with Trotter steps
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Hamiltonian Simulation - Heisenberg Model

# %%
# Bose Hubbard 1D grid nonpbc d=4
hamiltonian_name = 'condensedmatter/heisenberg/heis'
hamiltonian_params = { "1D-grid": "pbc", "h": 2 }

hamlib_simulation_benchmark.run(
            hamiltonian=hamiltonian_name, hamiltonian_params=hamiltonian_params,
            **app_args, **exec_args)
# Out:
# Hamiltonian Simulation Benchmark Program - cudaq
# ... hamiltonian and params = condensedmatter/heisenberg/heis, {'1D-grid': 'pbc', 'h': 2}
# ... group_method = SpinOperator
# ... execution starting at Jun 14, 2026 23:21:27 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 4
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-4_h-2
# ... number of terms in Hamiltonian = 16
# ... total elapsed execution time = 0.086
# ... exact computation time = 0.008 sec
#
#     Exact expectation value, computed classically: -4.0
#     Estimated expectation value, from quantum algorithm: -4.9876
#     ==> Simulation Quality: 1.247
#
# ************
# Executing [1] circuits with num_qubits = 5
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-5_h-2
# ... number of terms in Hamiltonian = 20
# ... total elapsed execution time = 0.002
# ... exact computation time = 0.012 sec
#
#     Exact expectation value, computed classically: -1.0
#     Estimated expectation value, from quantum algorithm: -5.9878
#     ==> Simulation Quality: 5.988
#
# ************
# Executing [1] circuits with num_qubits = 6
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-6_h-2
# ... number of terms in Hamiltonian = 24
# ... total elapsed execution time = 0.003
# ... exact computation time = 0.017 sec
#
#     Exact expectation value, computed classically: -6.0
#     Estimated expectation value, from quantum algorithm: -6.9767
#     ==> Simulation Quality: 1.163
#
# ************
# Executing [1] circuits with num_qubits = 7
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-7_h-2
# ... number of terms in Hamiltonian = 28
# ... total elapsed execution time = 0.003
# ... exact computation time = 0.023 sec
#
#     Exact expectation value, computed classically: -3.0
#     Estimated expectation value, from quantum algorithm: -7.9825
#     ==> Simulation Quality: 2.661
#
# ************
# Executing [1] circuits with num_qubits = 8
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-8_h-2
# ... number of terms in Hamiltonian = 32
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.03 sec
#
#     Exact expectation value, computed classically: -8.0
#     Estimated expectation value, from quantum algorithm: -8.9767
#     ==> Simulation Quality: 1.122
#
# ************
# Executing [1] circuits with num_qubits = 9
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-9_h-2
# ... number of terms in Hamiltonian = 36
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.039 sec
#
#     Exact expectation value, computed classically: -5.0
#     Estimated expectation value, from quantum algorithm: -9.9823
#     ==> Simulation Quality: 1.996
#
# ************
# Executing [1] circuits with num_qubits = 10
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-10_h-2
# ... number of terms in Hamiltonian = 40
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.049 sec
#
#     Exact expectation value, computed classically: -10.0
#     Estimated expectation value, from quantum algorithm: -10.9767
#     ==> Simulation Quality: 1.098
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-2
# ... number of terms in Hamiltonian = 48
# ... total elapsed execution time = 0.006
# ... exact computation time = 0.078 sec
#
#     Exact expectation value, computed classically: -12.0
#     Estimated expectation value, from quantum algorithm: -12.9767
#     ==> Simulation Quality: 1.081
#
# ************
# Executing [1] circuits with num_qubits = 14
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-14_h-2
# ... number of terms in Hamiltonian = 56
# ... total elapsed execution time = 0.007
# ... exact computation time = 0.16 sec
#
#     Exact expectation value, computed classically: -14.0
#     Estimated expectation value, from quantum algorithm: -14.9767
#     ==> Simulation Quality: 1.07
#
# ************
# Executing [1] circuits with num_qubits = 16
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-16_h-2
# ... number of terms in Hamiltonian = 64
# ... total elapsed execution time = 0.008
# ... exact computation time = 0.423 sec
#
#     Exact expectation value, computed classically: -16.0
#     Estimated expectation value, from quantum algorithm: -16.9767
#     ==> Simulation Quality: 1.061
#
# ************
# Executing [1] circuits with num_qubits = 18
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-18_h-2
# ... number of terms in Hamiltonian = 72
# ... total elapsed execution time = 0.014
#
#     Estimated expectation value, from quantum algorithm: -18.9767
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-20_h-2
# ... number of terms in Hamiltonian = 80
# ... total elapsed execution time = 0.015
#
#     Estimated expectation value, from quantum algorithm: -20.9768
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-22_h-2
# ... number of terms in Hamiltonian = 88
# ... total elapsed execution time = 0.03
#
#     Estimated expectation value, from quantum algorithm: -22.9768
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ... dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-24_h-2
# ... number of terms in Hamiltonian = 96
# ... total elapsed execution time = 0.281
#
#     Estimated expectation value, from quantum algorithm: -24.9768
#     ==> Simulation Quality: 0.0
#
# ... execution complete at Jun 14, 2026 23:21:28 UTC in 1.348 secs
#
# Sample Circuit:
# WARNING: cudaq cannot draw kernels with Trotter steps
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Hamiltonian Simulation - Fermi-Hubbard Model

# %%
# Bose Hubbard 1D grid nonpbc d=4
hamiltonian_name = 'condensedmatter/fermihubbard/FH_D-1'
hamiltonian_params = { "1D-grid": "pbc", "enc": "bk", "U":12 }

hamlib_simulation_benchmark.run(
            hamiltonian=hamiltonian_name, hamiltonian_params=hamiltonian_params,
            **app_args, **exec_args)
# Out:
# Hamiltonian Simulation Benchmark Program - cudaq
# ... hamiltonian and params = condensedmatter/fermihubbard/FH_D-1, {'1D-grid': 'pbc', 'enc': 'bk', 'U': 12}
# ... group_method = SpinOperator
# ... execution starting at Jun 14, 2026 23:21:30 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 4
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-2_U-12_enc-bk
# ... number of terms in Hamiltonian = 11
# ... total elapsed execution time = 0.074
# ... exact computation time = 0.006 sec
#
#     Exact expectation value, computed classically: -0.0
#     Estimated expectation value, from quantum algorithm: -0.9896
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 6
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-3_U-12_enc-bk
# ... number of terms in Hamiltonian = 22
# ... total elapsed execution time = 0.002
# ... exact computation time = 0.019 sec
#
#     Exact expectation value, computed classically: -0.0
#     Estimated expectation value, from quantum algorithm: -0.9571
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 8
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-4_U-12_enc-bk
# ... number of terms in Hamiltonian = 29
# ... total elapsed execution time = 0.003
# ... exact computation time = 0.028 sec
#
#     Exact expectation value, computed classically: 12.0
#     Estimated expectation value, from quantum algorithm: 10.7324
#     ==> Simulation Quality: 0.894
#
# ************
# Executing [1] circuits with num_qubits = 10
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-5_U-12_enc-bk
# ... number of terms in Hamiltonian = 36
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.043 sec
#
#     Exact expectation value, computed classically: 0.0
#     Estimated expectation value, from quantum algorithm: -1.0826
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-6_U-12_enc-bk
# ... number of terms in Hamiltonian = 43
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.076 sec
#
#     Exact expectation value, computed classically: 12.0
#     Estimated expectation value, from quantum algorithm: 10.7896
#     ==> Simulation Quality: 0.899
#
# ************
# Executing [1] circuits with num_qubits = 14
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-7_U-12_enc-bk
# ... number of terms in Hamiltonian = 50
# ... total elapsed execution time = 0.006
# ... exact computation time = 0.14 sec
#
#     Exact expectation value, computed classically: 0.0
#     Estimated expectation value, from quantum algorithm: -0.9541
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-8_U-12_enc-bk
# ... number of terms in Hamiltonian = 57
# ... total elapsed execution time = 0.013
# ... exact computation time = 0.381 sec
#
#     Exact expectation value, computed classically: 24.0
#     Estimated expectation value, from quantum algorithm: 22.6251
#     ==> Simulation Quality: 0.943
#
# ************
# Executing [1] circuits with num_qubits = 18
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-9_U-12_enc-bk
# ... number of terms in Hamiltonian = 64
# ... total elapsed execution time = 0.009
#
#     Estimated expectation value, from quantum algorithm: -0.9455
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-10_U-12_enc-bk
# ... number of terms in Hamiltonian = 71
# ... total elapsed execution time = 0.012
#
#     Estimated expectation value, from quantum algorithm: 10.8263
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ... dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-12_U-12_enc-bk
# ... number of terms in Hamiltonian = 85
# ... total elapsed execution time = 0.137
#
#     Estimated expectation value, from quantum algorithm: 34.3009
#     ==> Simulation Quality: 0.0
#
# ... execution complete at Jun 14, 2026 23:21:31 UTC in 0.984 secs
#
# Sample Circuit:
# WARNING: cudaq cannot draw kernels with Trotter steps
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Hamiltonian Simulation - Bose-Hubbard Model

# %%
# Bose Hubbard 1D grid nonpbc d=4
hamiltonian_name = 'condensedmatter/bosehubbard/BH_D-1_d-4'
hamiltonian_params = { "1D-grid": "nonpbc", "enc": "gray", "U":10 }

hamlib_simulation_benchmark.run(
            hamiltonian=hamiltonian_name, hamiltonian_params=hamiltonian_params,
            **app_args, **exec_args)
# Out:
# Hamiltonian Simulation Benchmark Program - cudaq
# ... hamiltonian and params = condensedmatter/bosehubbard/BH_D-1_d-4, {'1D-grid': 'nonpbc', 'enc': 'gray', 'U': 10}
# ... group_method = SpinOperator
# ... execution starting at Jun 14, 2026 23:21:35 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 4
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 39
# ... total elapsed execution time = 0.074
# ... exact computation time = 0.017 sec
#
#     Exact expectation value, computed classically: 60.0
#     Estimated expectation value, from quantum algorithm: 58.9823
#     ==> Simulation Quality: 0.983
#
# ************
# Executing [1] circuits with num_qubits = 6
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-3_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 74
# ... total elapsed execution time = 0.007
# ... exact computation time = 0.048 sec
#
#     Exact expectation value, computed classically: 90.0
#     Estimated expectation value, from quantum algorithm: 88.9648
#     ==> Simulation Quality: 0.988
#
# ************
# Executing [1] circuits with num_qubits = 8
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-4_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 109
# ... total elapsed execution time = 0.012
# ... exact computation time = 0.104 sec
#
#     Exact expectation value, computed classically: 120.0
#     Estimated expectation value, from quantum algorithm: 118.9473
#     ==> Simulation Quality: 0.991
#
# ************
# Executing [1] circuits with num_qubits = 10
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 144
# ... total elapsed execution time = 0.018
# ... exact computation time = 0.179 sec
#
#     Exact expectation value, computed classically: 150.0
#     Estimated expectation value, from quantum algorithm: 148.9297
#     ==> Simulation Quality: 0.993
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-6_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 179
# ... total elapsed execution time = 0.025
# ... exact computation time = 0.308 sec
#
#     Exact expectation value, computed classically: 180.0
#     Estimated expectation value, from quantum algorithm: 178.912
#     ==> Simulation Quality: 0.994
#
# ************
# Executing [1] circuits with num_qubits = 14
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-7_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 214
# ... total elapsed execution time = 0.03
# ... exact computation time = 0.572 sec
#
#     Exact expectation value, computed classically: 210.0
#     Estimated expectation value, from quantum algorithm: 208.8941
#     ==> Simulation Quality: 0.995
#
# ************
# Executing [1] circuits with num_qubits = 16
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-8_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 249
# ... total elapsed execution time = 0.04
# ... exact computation time = 1.681 sec
#
#     Exact expectation value, computed classically: 240.0
#     Estimated expectation value, from quantum algorithm: 238.8766
#     ==> Simulation Quality: 0.995
#
# ************
# Executing [1] circuits with num_qubits = 18
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-9_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 284
# ... total elapsed execution time = 0.053
#
#     Estimated expectation value, from quantum algorithm: 268.8587
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 319
# ... total elapsed execution time = 0.091
#
#     Estimated expectation value, from quantum algorithm: 298.8406
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ... dataset_name = bh_graph-1D-grid-nonpbc-qubitnodes_Lx-12_U-10_enc-gray_d-4
# ... number of terms in Hamiltonian = 389
# ... total elapsed execution time = 0.473
#
#     Estimated expectation value, from quantum algorithm: 358.8051
#     ==> Simulation Quality: 0.0
#
# ... execution complete at Jun 14, 2026 23:21:38 UTC in 3.753 secs
#
# Sample Circuit:
# WARNING: cudaq cannot draw kernels with Trotter steps
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Hamiltonian Simulation - Random Max3Sat

# %%
# Max3Sat - ratio 2 rinst 02
hamiltonian_name = 'binaryoptimization/max3sat/random/random_max3sat-hams'
hamiltonian_params = { "ratio": "2", "rinst": "02" }

hamlib_simulation_benchmark.run(
            hamiltonian=hamiltonian_name, hamiltonian_params=hamiltonian_params,
            **app_args, **exec_args)
# Out:
# Hamiltonian Simulation Benchmark Program - cudaq
# ... hamiltonian and params = binaryoptimization/max3sat/random/random_max3sat-hams, {'ratio': '2', 'rinst': '02'}
# ... group_method = SpinOperator
# ... execution starting at Jun 14, 2026 23:21:42 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 4
# ... dataset_name = max3sat_n-4_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 12
# ... total elapsed execution time = 0.071
# ... exact computation time = 0.006 sec
#
#     Exact expectation value, computed classically: 7.0
#     Estimated expectation value, from quantum algorithm: 6.0
#     ==> Simulation Quality: 0.857
#
# ************
# Executing [1] circuits with num_qubits = 5
# ... dataset_name = max3sat_n-5_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 17
# ... total elapsed execution time = 0.002
# ... exact computation time = 0.009 sec
#
#     Exact expectation value, computed classically: 8.0
#     Estimated expectation value, from quantum algorithm: 7.0
#     ==> Simulation Quality: 0.875
#
# ************
# Executing [1] circuits with num_qubits = 6
# ... dataset_name = max3sat_n-6_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 22
# ... total elapsed execution time = 0.002
# ... exact computation time = 0.015 sec
#
#     Exact expectation value, computed classically: 10.0
#     Estimated expectation value, from quantum algorithm: 9.0
#     ==> Simulation Quality: 0.9
#
# ************
# Executing [1] circuits with num_qubits = 7
# ... dataset_name = max3sat_n-7_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 32
# ... total elapsed execution time = 0.003
# ... exact computation time = 0.025 sec
#
#     Exact expectation value, computed classically: 10.0
#     Estimated expectation value, from quantum algorithm: 13.0
#     ==> Simulation Quality: 1.3
#
# ************
# Executing [1] circuits with num_qubits = 8
# ... dataset_name = max3sat_n-8_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 38
# ... total elapsed execution time = 0.004
# ... exact computation time = 0.034 sec
#
#     Exact expectation value, computed classically: 14.0
#     Estimated expectation value, from quantum algorithm: 13.0
#     ==> Simulation Quality: 0.929
#
# ************
# Executing [1] circuits with num_qubits = 9
# ... dataset_name = max3sat_n-9_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 47
# ... total elapsed execution time = 0.006
# ... exact computation time = 0.052 sec
#
#     Exact expectation value, computed classically: 16.0
#     Estimated expectation value, from quantum algorithm: 14.0
#     ==> Simulation Quality: 0.875
#
# ************
# Executing [1] circuits with num_qubits = 10
# ... dataset_name = max3sat_n-10_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 58
# ... total elapsed execution time = 0.007
# ... exact computation time = 0.069 sec
#
#     Exact expectation value, computed classically: 15.0
#     Estimated expectation value, from quantum algorithm: 14.0
#     ==> Simulation Quality: 0.933
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... dataset_name = max3sat_n-12_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 68
# ... total elapsed execution time = 0.009
# ... exact computation time = 0.106 sec
#
#     Exact expectation value, computed classically: 21.0
#     Estimated expectation value, from quantum algorithm: 19.9999
#     ==> Simulation Quality: 0.952
#
# ************
# Executing [1] circuits with num_qubits = 14
# ... dataset_name = max3sat_n-14_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 87
# ... total elapsed execution time = 0.012
# ... exact computation time = 0.217 sec
#
#     Exact expectation value, computed classically: 26.0
#     Estimated expectation value, from quantum algorithm: 24.9999
#     ==> Simulation Quality: 0.962
#
# ************
# Executing [1] circuits with num_qubits = 16
# ... dataset_name = max3sat_n-16_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 104
# ... total elapsed execution time = 0.015
# ... exact computation time = 0.534 sec
#
#     Exact expectation value, computed classically: 30.0
#     Estimated expectation value, from quantum algorithm: 28.9999
#     ==> Simulation Quality: 0.967
#
# ************
# Executing [1] circuits with num_qubits = 18
# ... dataset_name = max3sat_n-18_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 117
# ... total elapsed execution time = 0.02
#
#     Estimated expectation value, from quantum algorithm: 31.9999
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ... dataset_name = max3sat_n-20_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 148
# ... total elapsed execution time = 0.037
#
#     Estimated expectation value, from quantum algorithm: 35.9998
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ... dataset_name = max3sat_n-22_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 156
# ... total elapsed execution time = 0.095
#
#     Estimated expectation value, from quantum algorithm: 32.9998
#     ==> Simulation Quality: 0.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ... dataset_name = max3sat_n-24_ratio-2_rinst-02
# ... number of terms in Hamiltonian = 179
# ... total elapsed execution time = 0.198
#
#     Estimated expectation value, from quantum algorithm: 38.9997
#     ==> Simulation Quality: 0.0
#
# ... execution complete at Jun 14, 2026 23:21:43 UTC in 1.573 secs
#
# Sample Circuit:
# WARNING: cudaq cannot draw kernels with Trotter steps
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Hamiltonian Simulation - H2

# %%
# H2 - BK encoding
hamiltonian_name = 'chemistry/electronic/standard/H2'
hamiltonian_params = { "ham_BK": "" }

hamlib_simulation_benchmark.run(
            hamiltonian=hamiltonian_name, hamiltonian_params=hamiltonian_params,
            **app_args, **exec_args)
# Out:
# Hamiltonian Simulation Benchmark Program - cudaq
# ... hamiltonian and params = chemistry/electronic/standard/H2, {'ham_BK': ''}
# ... group_method = SpinOperator
# ... execution starting at Jun 14, 2026 23:21:44 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 4
# ... dataset_name = ham_BK-4
# ... number of terms in Hamiltonian = 15
# ... total elapsed execution time = 0.063
# ... exact computation time = 0.008 sec
#
#     Exact expectation value, computed classically: -0.5367
#     Estimated expectation value, from quantum algorithm: -1.5367
#     ==> Simulation Quality: 2.863
#
# ************
# Executing [1] circuits with num_qubits = 6
# ... dataset_name = ham_BK-6
# ... number of terms in Hamiltonian = 62
# ... total elapsed execution time = 0.005
# ... exact computation time = 0.044 sec
#
#     Exact expectation value, computed classically: -0.5102
#     Estimated expectation value, from quantum algorithm: -1.5102
#     ==> Simulation Quality: 2.96
#
# ************
# Executing [1] circuits with num_qubits = 8
# ... dataset_name = ham_BK-8
# ... number of terms in Hamiltonian = 185
# ... total elapsed execution time = 0.014
# ... exact computation time = 0.188 sec
#
#     Exact expectation value, computed classically: 0.2017
#     Estimated expectation value, from quantum algorithm: -0.7983
#     ==> Simulation Quality: -3.958
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... dataset_name = ham_BK-12
# ... number of terms in Hamiltonian = 327
# ... total elapsed execution time = 0.03
# ... exact computation time = 0.63 sec
#
#     Exact expectation value, computed classically: 1.7957
#     Estimated expectation value, from quantum algorithm: 0.7957
#     ==> Simulation Quality: 0.443
#
# ************
# Executing [1] circuits with num_qubits = 20
# ... dataset_name = ham_BK-20
# ... number of terms in Hamiltonian = 2951
# ... total elapsed execution time = 0.512
#
#     Estimated expectation value, from quantum algorithm: 6.9739
#     ==> Simulation Quality: 0.0
#
# ... execution complete at Jun 14, 2026 23:21:45 UTC in 1.525 secs
#
# Sample Circuit:
# WARNING: cudaq cannot draw kernels with Trotter steps
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Hamiltonian Simulation - LiH

# %%
# H2 - BK encoding
hamiltonian_name = 'chemistry/electronic/standard/LiH'
hamiltonian_params = { "ham_BK": "" }

hamlib_simulation_benchmark.run(
            hamiltonian=hamiltonian_name, hamiltonian_params=hamiltonian_params,
            **app_args, **exec_args)
# Out:
# Hamiltonian Simulation Benchmark Program - cudaq
# ... hamiltonian and params = chemistry/electronic/standard/LiH, {'ham_BK': ''}
# ... group_method = SpinOperator
# ... execution starting at Jun 14, 2026 23:21:46 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 4
# ... dataset_name = ham_BK-4
# ... number of terms in Hamiltonian = 27
# ... total elapsed execution time = 0.079
# ... exact computation time = 0.013 sec
#
#     Exact expectation value, computed classically: -7.6831
#     Estimated expectation value, from quantum algorithm: -8.6831
#     ==> Simulation Quality: 1.13
#
# ************
# Executing [1] circuits with num_qubits = 8
# ... dataset_name = ham_BK-8
# ... number of terms in Hamiltonian = 105
# ... total elapsed execution time = 0.009
# ... exact computation time = 0.095 sec
#
#     Exact expectation value, computed classically: -7.7889
#     Estimated expectation value, from quantum algorithm: -8.7889
#     ==> Simulation Quality: 1.128
#
# ************
# Executing [1] circuits with num_qubits = 10
# ... dataset_name = ham_BK-10
# ... number of terms in Hamiltonian = 276
# ... total elapsed execution time = 0.027
# ... exact computation time = 0.357 sec
#
#     Exact expectation value, computed classically: -7.6506
#     Estimated expectation value, from quantum algorithm: -8.6506
#     ==> Simulation Quality: 1.131
#
# ************
# Executing [1] circuits with num_qubits = 12
# ... dataset_name = ham_BK-12
# ... number of terms in Hamiltonian = 631
# ... total elapsed execution time = 0.066
# ... exact computation time = 1.167 sec
#
#     Exact expectation value, computed classically: -7.6506
#     Estimated expectation value, from quantum algorithm: -8.6506
#     ==> Simulation Quality: 1.131
#
# ... execution complete at Jun 14, 2026 23:21:48 UTC in 1.824 secs
#
# Sample Circuit:
# WARNING: cudaq cannot draw kernels with Trotter steps
# ----- Expectation Value Plot -----
# ----- Expectation Time Plot -----

# %% [markdown]
# ### Combined Benchmark Results

# %%
import cudaq
print(cudaq.__version__)
# Out:
# CUDA-Q Version amd64-cu12-0.13.0 (https://github.com/NVIDIA/cuda-quantum b66c5bb7fd8c08e5014e2f03e97e7b0e92691650)
