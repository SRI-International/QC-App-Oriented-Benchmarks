# %% [markdown]
# # QED-C Benchmark Suite - CUDA-Q
# This notebook runs the standard fidelity-based benchmarks using the CUDA-Q API on GPU simulators. Each cell executes one benchmark end-to-end using `benchmark.run()`, which creates circuits, executes them, computes fidelity, and plots results. A second section re-runs the benchmarks with a noise model for comparison.
#
# Configure the first cell with your backend and execution settings, then run the benchmark cells of interest.
#
# > **Note:** Some benchmarks (HamLib) have more complex workflows and provide their own notebooks in their respective directories under `qedcbench/`.

# %%
# Benchmark application settings
app_args = dict(
    min_qubits = 2,
    max_qubits = 24,
    skip_qubits = 1,
    max_circuits = 1,
    num_shots = 1000,
    api = "cudaq",
)

# Default execution settings
exec_args = dict(
    backend_id = "nvidia",
    #backend_id = "density-matrix-cpu",    # for noisy simulation
    
    hub = "", group = "", project = "",
    provider_backend = None,
    exec_options = {},
    
    # # To enable noise model, uncomment one of these in exec_options above:
    # #   "noise_model": "default"     - built-in depolarization model
    # #   "noise_model": None          - explicitly no noise
    # #   "noise_model": my_model      - custom cudaq.NoiseModel object
)

# # Uncomment these lines to add a suffix to your backend_id and data/image files
# from _common import metrics
# metrics.data_suffix = "-mysystem"

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
from bernstein_vazirani import bv_benchmark
bv_benchmark.run(method=1, **app_args, **exec_args)
# Out:
# ... execution starting at May 13, 2026 13:38:12 UTC
# ************
# Creating [1] circuits with num_qubits = 3
# ************
# Creating [1] circuits with num_qubits = 4
# ************
# Creating [1] circuits with num_qubits = 5
# ************
# Creating [1] circuits with num_qubits = 6
# ************
# Creating [1] circuits with num_qubits = 7
# ************
# Creating [1] circuits with num_qubits = 8
# ************
# Creating [1] circuits with num_qubits = 9
# ************
# Creating [1] circuits with num_qubits = 10
# ************
# Creating [1] circuits with num_qubits = 11
# ************
# Creating [1] circuits with num_qubits = 12
# ************
# Creating [1] circuits with num_qubits = 13
# ************
# Creating [1] circuits with num_qubits = 14
# ************
# Creating [1] circuits with num_qubits = 15
# ************
# Creating [1] circuits with num_qubits = 16
# ************
# Creating [1] circuits with num_qubits = 17
# ************
# Creating [1] circuits with num_qubits = 18
# ************
# Creating [1] circuits with num_qubits = 19
# ************
# Creating [1] circuits with num_qubits = 20
# ************
# Creating [1] circuits with num_qubits = 21
# ************
# Creating [1] circuits with num_qubits = 22
# ************
# Creating [1] circuits with num_qubits = 23
# ************
# Creating [1] circuits with num_qubits = 24
# ... configure execution for target backend_id = nvidia
# ************
# Average Circuit Algorithmic Depth, xi for the 3 qubit group = 5, 0.143
# Average Normalized Transpiled Depth, xi, 2q gates for the 3 qubit group = 5, 0.143, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 4 qubit group = 5, 0.111
# Average Normalized Transpiled Depth, xi, 2q gates for the 4 qubit group = 5, 0.111, 1.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 5 qubit group = 5, 0.091
# Average Normalized Transpiled Depth, xi, 2q gates for the 5 qubit group = 5, 0.091, 1.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 6 qubit group = 7, 0.2
# Average Normalized Transpiled Depth, xi, 2q gates for the 6 qubit group = 7, 0.2, 3.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 7 qubit group = 6, 0.125
# Average Normalized Transpiled Depth, xi, 2q gates for the 7 qubit group = 6, 0.125, 2.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 8 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, xi, 2q gates for the 8 qubit group = 8, 0.2, 4.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 9 qubit group = 6, 0.1
# Average Normalized Transpiled Depth, xi, 2q gates for the 9 qubit group = 6, 0.1, 2.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 10 qubit group = 7, 0.13
# Average Normalized Transpiled Depth, xi, 2q gates for the 10 qubit group = 7, 0.13, 3.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 11 qubit group = 9, 0.185
# Average Normalized Transpiled Depth, xi, 2q gates for the 11 qubit group = 9, 0.185, 5.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 12 qubit group = 7, 0.111
# Average Normalized Transpiled Depth, xi, 2q gates for the 12 qubit group = 7, 0.111, 3.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 13 qubit group = 10, 0.188
# Average Normalized Transpiled Depth, xi, 2q gates for the 13 qubit group = 10, 0.188, 6.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 14 qubit group = 11, 0.2
# Average Normalized Transpiled Depth, xi, 2q gates for the 14 qubit group = 11, 0.2, 7.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 15 qubit group = 9, 0.143
# Average Normalized Transpiled Depth, xi, 2q gates for the 15 qubit group = 9, 0.143, 5.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 16 qubit group = 14, 0.22
# Average Normalized Transpiled Depth, xi, 2q gates for the 16 qubit group = 14, 0.22, 9.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 17 qubit group = 14, 0.209
# Average Normalized Transpiled Depth, xi, 2q gates for the 17 qubit group = 14, 0.209, 9.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 18 qubit group = 10, 0.143
# Average Normalized Transpiled Depth, xi, 2q gates for the 18 qubit group = 10, 0.143, 6.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 19 qubit group = 12, 0.174
# Average Normalized Transpiled Depth, xi, 2q gates for the 19 qubit group = 12, 0.174, 8.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 20 qubit group = 13, 0.184
# Average Normalized Transpiled Depth, xi, 2q gates for the 20 qubit group = 13, 0.184, 9.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 21 qubit group = 13, 0.176
# Average Normalized Transpiled Depth, xi, 2q gates for the 21 qubit group = 13, 0.176, 9.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 22 qubit group = 14, 0.185
# Average Normalized Transpiled Depth, xi, 2q gates for the 22 qubit group = 14, 0.185, 10.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 23 qubit group = 18, 0.22
# Average Normalized Transpiled Depth, xi, 2q gates for the 23 qubit group = 18, 0.22, 13.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 24 qubit group = 13, 0.158
# Average Normalized Transpiled Depth, xi, 2q gates for the 24 qubit group = 13, 0.158, 9.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.0, 0.008, 0.008 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ... execution complete at May 13, 2026 13:38:16 UTC in 3.871 secs
#
# Sample Circuit:
#      ╭───╮                    ╭───╮
# q0 : ┤ h ├─────────────────●──┤ h ├
#      ├───┤                 │  ├───┤
# q1 : ┤ h ├─────────────────┼──┤ h ├
#      ├───┤                 │  ├───┤
# q2 : ┤ h ├─────────────────┼──┤ h ├
#      ├───┤                 │  ├───┤
# q3 : ┤ h ├────────────●────┼──┤ h ├
#      ├───┤            │    │  ├───┤
# q4 : ┤ h ├───────●────┼────┼──┤ h ├
#      ├───┤╭───╮╭─┴─╮╭─┴─╮╭─┴─╮╰───╯
# q5 : ┤ h ├┤ z ├┤ x ├┤ x ├┤ x ├─────
#      ╰───╯╰───╯╰───╯╰───╯╰───╯

# %% [markdown]
# ### Hidden Shift

# %%
from hidden_shift import hs_benchmark
hs_benchmark.run(**app_args, **exec_args)
# Out:
# ... execution starting at May 13, 2026 13:38:18 UTC
# ************
# Creating [1] circuits with num_qubits = 2
# ************
# Creating [1] circuits with num_qubits = 4
# ************
# Creating [1] circuits with num_qubits = 6
# ************
# Creating [1] circuits with num_qubits = 8
# ************
# Creating [1] circuits with num_qubits = 10
# ************
# Creating [1] circuits with num_qubits = 12
# ************
# Creating [1] circuits with num_qubits = 14
# ************
# Creating [1] circuits with num_qubits = 16
# ************
# Creating [1] circuits with num_qubits = 18
# ************
# Creating [1] circuits with num_qubits = 20
# ************
# Creating [1] circuits with num_qubits = 22
# ************
# Creating [1] circuits with num_qubits = 24
# ... configure execution for target backend_id = nvidia
# ************
# Average Circuit Algorithmic Depth, xi for the 2 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, xi, 2q gates for the 2 qubit group = 8, 0.2, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 4 qubit group = 10, 0.222
# Average Normalized Transpiled Depth, xi, 2q gates for the 4 qubit group = 10, 0.222, 4.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 6 qubit group = 12, 0.231
# Average Normalized Transpiled Depth, xi, 2q gates for the 6 qubit group = 12, 0.231, 6.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 8 qubit group = 14, 0.222
# Average Normalized Transpiled Depth, xi, 2q gates for the 8 qubit group = 14, 0.222, 8.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 10 qubit group = 16, 0.227
# Average Normalized Transpiled Depth, xi, 2q gates for the 10 qubit group = 16, 0.227, 10.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 12 qubit group = 18, 0.222
# Average Normalized Transpiled Depth, xi, 2q gates for the 12 qubit group = 18, 0.222, 12.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 14 qubit group = 20, 0.212
# Average Normalized Transpiled Depth, xi, 2q gates for the 14 qubit group = 20, 0.212, 14.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 16 qubit group = 22, 0.2
# Average Normalized Transpiled Depth, xi, 2q gates for the 16 qubit group = 22, 0.2, 16.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 18 qubit group = 24, 0.2
# Average Normalized Transpiled Depth, xi, 2q gates for the 18 qubit group = 24, 0.2, 18.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 20 qubit group = 26, 0.213
# Average Normalized Transpiled Depth, xi, 2q gates for the 20 qubit group = 26, 0.213, 20.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 22 qubit group = 28, 0.204
# Average Normalized Transpiled Depth, xi, 2q gates for the 22 qubit group = 28, 0.204, 22.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 24 qubit group = 30, 0.203
# Average Normalized Transpiled Depth, xi, 2q gates for the 24 qubit group = 30, 0.203, 24.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ... execution complete at May 13, 2026 13:38:18 UTC in 0.349 secs
#
# Sample Circuit:
#      ╭───╮     ╭───╮     ╭───╮
# q0 : ┤ h ├──●──┤ h ├──●──┤ h ├──────────
#      ├───┤╭─┴─╮├───┤╭─┴─╮├───┤
# q1 : ┤ h ├┤ z ├┤ h ├┤ z ├┤ h ├──────────
#      ├───┤╰───╯├───┤╰───╯├───┤
# q2 : ┤ h ├──●──┤ h ├──●──┤ h ├──────────
#      ├───┤╭─┴─╮├───┤╭─┴─╮├───┤
# q3 : ┤ h ├┤ z ├┤ h ├┤ z ├┤ h ├──────────
#      ├───┤╰───╯╰───╯├───┤╰───╯     ╭───╮
# q4 : ┤ h ├───────●──┤ h ├───────●──┤ h ├
#      ├───┤╭───╮╭─┴─╮├───┤╭───╮╭─┴─╮├───┤
# q5 : ┤ h ├┤ x ├┤ z ├┤ x ├┤ h ├┤ z ├┤ h ├
#      ╰───╯╰───╯╰───╯╰───╯╰───╯╰───╯╰───╯

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
from quantum_fourier_transform import qft_benchmark
qft_benchmark.run(method=1, **app_args, **exec_args)
# Out:
# ... execution starting at May 13, 2026 13:38:19 UTC
# ************
# Creating [1] circuits with num_qubits = 2
# ************
# Creating [1] circuits with num_qubits = 3
# ************
# Creating [1] circuits with num_qubits = 4
# ************
# Creating [1] circuits with num_qubits = 5
# ************
# Creating [1] circuits with num_qubits = 6
# ************
# Creating [1] circuits with num_qubits = 7
# ************
# Creating [1] circuits with num_qubits = 8
# ************
# Creating [1] circuits with num_qubits = 9
# ************
# Creating [1] circuits with num_qubits = 10
# ************
# Creating [1] circuits with num_qubits = 11
# ************
# Creating [1] circuits with num_qubits = 12
# ************
# Creating [1] circuits with num_qubits = 13
# ************
# Creating [1] circuits with num_qubits = 14
# ************
# Creating [1] circuits with num_qubits = 15
# ************
# Creating [1] circuits with num_qubits = 16
# ************
# Creating [1] circuits with num_qubits = 17
# ************
# Creating [1] circuits with num_qubits = 18
# ************
# Creating [1] circuits with num_qubits = 19
# ************
# Creating [1] circuits with num_qubits = 20
# ************
# Creating [1] circuits with num_qubits = 21
# ************
# Creating [1] circuits with num_qubits = 22
# ************
# Creating [1] circuits with num_qubits = 23
# ************
# Creating [1] circuits with num_qubits = 24
# ... configure execution for target backend_id = nvidia
# ************
# Average Circuit Algorithmic Depth, xi for the 2 qubit group = 8, 0.222
# Average Normalized Transpiled Depth, xi, 2q gates for the 2 qubit group = 8, 0.222, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 3 qubit group = 12, 0.375
# Average Normalized Transpiled Depth, xi, 2q gates for the 3 qubit group = 12, 0.375, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 4 qubit group = 19, 0.48
# Average Normalized Transpiled Depth, xi, 2q gates for the 4 qubit group = 19, 0.48, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 5 qubit group = 27, 0.556
# Average Normalized Transpiled Depth, xi, 2q gates for the 5 qubit group = 27, 0.556, 20.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 6 qubit group = 37, 0.612
# Average Normalized Transpiled Depth, xi, 2q gates for the 6 qubit group = 37, 0.612, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 7 qubit group = 50, 0.618
# Average Normalized Transpiled Depth, xi, 2q gates for the 7 qubit group = 50, 0.618, 42.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 8 qubit group = 63, 0.675
# Average Normalized Transpiled Depth, xi, 2q gates for the 8 qubit group = 63, 0.675, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 9 qubit group = 79, 0.706
# Average Normalized Transpiled Depth, xi, 2q gates for the 9 qubit group = 79, 0.706, 72.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 10 qubit group = 97, 0.732
# Average Normalized Transpiled Depth, xi, 2q gates for the 10 qubit group = 97, 0.732, 90.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 11 qubit group = 118, 0.748
# Average Normalized Transpiled Depth, xi, 2q gates for the 11 qubit group = 118, 0.748, 110.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 12 qubit group = 140, 0.763
# Average Normalized Transpiled Depth, xi, 2q gates for the 12 qubit group = 140, 0.763, 132.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 13 qubit group = 164, 0.78
# Average Normalized Transpiled Depth, xi, 2q gates for the 13 qubit group = 164, 0.78, 156.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 14 qubit group = 190, 0.795
# Average Normalized Transpiled Depth, xi, 2q gates for the 14 qubit group = 190, 0.795, 182.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 15 qubit group = 218, 0.805
# Average Normalized Transpiled Depth, xi, 2q gates for the 15 qubit group = 218, 0.805, 210.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 16 qubit group = 248, 0.814
# Average Normalized Transpiled Depth, xi, 2q gates for the 16 qubit group = 248, 0.814, 240.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 17 qubit group = 280, 0.822
# Average Normalized Transpiled Depth, xi, 2q gates for the 17 qubit group = 280, 0.822, 272.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 18 qubit group = 314, 0.832
# Average Normalized Transpiled Depth, xi, 2q gates for the 18 qubit group = 314, 0.832, 306.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 19 qubit group = 350, 0.84
# Average Normalized Transpiled Depth, xi, 2q gates for the 19 qubit group = 350, 0.84, 342.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 20 qubit group = 388, 0.848
# Average Normalized Transpiled Depth, xi, 2q gates for the 20 qubit group = 388, 0.848, 380.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.0, 0.006, 0.006 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 21 qubit group = 428, 0.855
# Average Normalized Transpiled Depth, xi, 2q gates for the 21 qubit group = 428, 0.855, 420.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.0, 0.006, 0.006 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 22 qubit group = 470, 0.86
# Average Normalized Transpiled Depth, xi, 2q gates for the 22 qubit group = 470, 0.86, 462.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.0, 0.006, 0.006 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 23 qubit group = 514, 0.866
# Average Normalized Transpiled Depth, xi, 2q gates for the 23 qubit group = 514, 0.866, 506.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.0, 0.007, 0.007 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 24 qubit group = 560, 0.872
# Average Normalized Transpiled Depth, xi, 2q gates for the 24 qubit group = 560, 0.872, 552.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.0, 0.019, 0.019 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ... execution complete at May 13, 2026 13:38:20 UTC in 0.469 secs
#
# Sample Circuit:
#      ╭───╮╭───────────╮     ╭────────────╮                  ╭────────────╮»
# q0 : ┤ h ├┤ r1(1.571) ├─────┤ r1(0.7854) ├──────────────────┤ r1(0.3927) ├»
#      ╰───╯╰─────┬─────╯╭───╮╰─────┬──────╯╭───────────╮     ╰─────┬──────╯»
# q1 : ───────────●──────┤ h ├──────┼───────┤ r1(1.571) ├───────────┼───────»
#                        ╰───╯      │       ╰─────┬─────╯╭───╮      │       »
# q2 : ─────────────────────────────●─────────────●──────┤ h ├──────┼───────»
#                                                        ╰───╯      │       »
# q3 : ─────────────────────────────────────────────────────────────●───────»
#                                                                           »
# q4 : ─────────────────────────────────────────────────────────────────────»
#      ╭───╮                                                                »
# q5 : ┤ x ├────────────────────────────────────────────────────────────────»
#      ╰───╯                                                                »
#
# ################################################################################
#
#                                 ╭────────────╮                            »
# ────────────────────────────────┤ r1(0.1963) ├────────────────────────────»
# ╭────────────╮                  ╰─────┬──────╯╭────────────╮              »
# ┤ r1(0.7854) ├────────────────────────┼───────┤ r1(0.3927) ├──────────────»
# ╰─────┬──────╯╭───────────╮           │       ╰─────┬──────╯╭────────────╮»
# ──────┼───────┤ r1(1.571) ├───────────┼─────────────┼───────┤ r1(0.7854) ├»
#       │       ╰─────┬─────╯╭───╮      │             │       ╰─────┬──────╯»
# ──────●─────────────●──────┤ h ├──────┼─────────────┼─────────────┼───────»
#                            ╰───╯      │             │             │       »
# ──────────────────────────────────────●─────────────●─────────────●───────»
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
#                                                                           »
#
# ################################################################################
#
#                   ╭─────────────╮╭─────────────╮                            »
# ──────────────────┤ r1(0.09817) ├┤ rz(0.09817) ├────────────────────────────»
#                   ╰──────┬──────╯├────────────┬╯╭────────────╮              »
# ─────────────────────────┼───────┤ r1(0.1963) ├─┤ rz(0.1963) ├──────────────»
#                          │       ╰─────┬──────╯ ├────────────┤╭────────────╮»
# ─────────────────────────┼─────────────┼────────┤ r1(0.3927) ├┤ rz(0.3927) ├»
# ╭───────────╮            │             │        ╰─────┬──────╯├────────────┤»
# ┤ r1(1.571) ├────────────┼─────────────┼──────────────┼───────┤ r1(0.7854) ├»
# ╰─────┬─────╯╭───╮       │             │              │       ╰─────┬──────╯»
# ──────●──────┤ h ├───────┼─────────────┼──────────────┼─────────────┼───────»
#              ╰───╯       │             │              │             │       »
# ─────────────────────────●─────────────●──────────────●─────────────●───────»
#                                                                             »
#
# ################################################################################
#
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
# ╭────────────╮                                             ╭─────────────╮»
# ┤ rz(0.7854) ├─────────────────────────────────────────────┤ r1(-0.7854) ├»
# ├───────────┬╯╭───────────╮                  ╭────────────╮╰──────┬──────╯»
# ┤ r1(1.571) ├─┤ rz(1.571) ├──────────────────┤ r1(-1.571) ├───────┼───────»
# ╰─────┬─────╯ ╰───┬───┬───╯╭───────────╮╭───╮╰─────┬──────╯       │       »
# ──────●───────────┤ h ├────┤ rz(3.142) ├┤ h ├──────●──────────────●───────»
#                   ╰───╯    ╰───────────╯╰───╯                             »
#
# ################################################################################
#
#                               ╭──────────────╮                   »
# ──────────────────────────────┤ r1(-0.09817) ├───────────────────»
#                ╭─────────────╮╰──────┬───────╯                   »
# ───────────────┤ r1(-0.1963) ├───────┼───────────────────────────»
# ╭─────────────╮╰──────┬──────╯       │                           »
# ┤ r1(-0.3927) ├───────┼──────────────┼───────────────────────────»
# ╰──────┬──────╯       │              │             ╭────────────╮»
# ───────┼──────────────┼──────────────┼─────────────┤ r1(-1.571) ├»
#        │              │              │        ╭───╮╰─────┬──────╯»
# ───────┼──────────────┼──────────────┼────────┤ h ├──────●───────»
#        │              │              │        ╰───╯              »
# ───────●──────────────●──────────────●───────────────────────────»
#                                                                  »
#
# ################################################################################
#
#                               ╭─────────────╮                   »
# ──────────────────────────────┤ r1(-0.1963) ├───────────────────»
#                ╭─────────────╮╰──────┬──────╯                   »
# ───────────────┤ r1(-0.3927) ├───────┼──────────────────────────»
# ╭─────────────╮╰──────┬──────╯       │            ╭────────────╮»
# ┤ r1(-0.7854) ├───────┼──────────────┼────────────┤ r1(-1.571) ├»
# ╰──────┬──────╯       │              │       ╭───╮╰─────┬──────╯»
# ───────┼──────────────┼──────────────┼───────┤ h ├──────●───────»
#        │              │              │       ╰───╯              »
# ───────●──────────────●──────────────●──────────────────────────»
#                                                                 »
# ────────────────────────────────────────────────────────────────»
#                                                                 »
#
# ################################################################################
#
#                ╭─────────────╮                   ╭─────────────╮     »
# ───────────────┤ r1(-0.3927) ├───────────────────┤ r1(-0.7854) ├─────»
# ╭─────────────╮╰──────┬──────╯     ╭────────────╮╰──────┬──────╯╭───╮»
# ┤ r1(-0.7854) ├───────┼────────────┤ r1(-1.571) ├───────┼───────┤ h ├»
# ╰──────┬──────╯       │       ╭───╮╰─────┬──────╯       │       ╰───╯»
# ───────┼──────────────┼───────┤ h ├──────●──────────────●────────────»
#        │              │       ╰───╯                                  »
# ───────●──────────────●──────────────────────────────────────────────»
#                                                                      »
# ─────────────────────────────────────────────────────────────────────»
#                                                                      »
# ─────────────────────────────────────────────────────────────────────»
#                                                                      »
#
# ################################################################################
#
# ╭────────────╮╭───╮
# ┤ r1(-1.571) ├┤ h ├
# ╰─────┬──────╯╰───╯
# ──────●────────────
#
# ───────────────────
#
# ───────────────────
#
# ───────────────────
#
# ───────────────────

# %% [markdown]
# ### Quantum Phase Estimation

# %%
from phase_estimation import pe_benchmark
pe_benchmark.run(**app_args, **exec_args)
# Out:
# ... execution starting at May 13, 2026 13:38:22 UTC
# ************
# Creating [1] circuits with num_qubits = 3
# ************
# Creating [1] circuits with num_qubits = 4
# ************
# Creating [1] circuits with num_qubits = 5
# ************
# Creating [1] circuits with num_qubits = 6
# ************
# Creating [1] circuits with num_qubits = 7
# ************
# Creating [1] circuits with num_qubits = 8
# ************
# Creating [1] circuits with num_qubits = 9
# ************
# Creating [1] circuits with num_qubits = 10
# ************
# Creating [1] circuits with num_qubits = 11
# ************
# Creating [1] circuits with num_qubits = 12
# ************
# Creating [1] circuits with num_qubits = 13
# ************
# Creating [1] circuits with num_qubits = 14
# ************
# Creating [1] circuits with num_qubits = 15
# ************
# Creating [1] circuits with num_qubits = 16
# ************
# Creating [1] circuits with num_qubits = 17
# ************
# Creating [1] circuits with num_qubits = 18
# ************
# Creating [1] circuits with num_qubits = 19
# ************
# Creating [1] circuits with num_qubits = 20
# ************
# Creating [1] circuits with num_qubits = 21
# ************
# Creating [1] circuits with num_qubits = 22
# ************
# Creating [1] circuits with num_qubits = 23
# ************
# Creating [1] circuits with num_qubits = 24
# ... configure execution for target backend_id = nvidia
# ************
# Average Circuit Algorithmic Depth, xi for the 3 qubit group = 8, 0.3
# Average Normalized Transpiled Depth, xi, 2q gates for the 3 qubit group = 8, 0.3, 3.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 4 qubit group = 11, 0.4
# Average Normalized Transpiled Depth, xi, 2q gates for the 4 qubit group = 11, 0.4, 6.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 5 qubit group = 15, 0.435
# Average Normalized Transpiled Depth, xi, 2q gates for the 5 qubit group = 15, 0.435, 10.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 6 qubit group = 20, 0.5
# Average Normalized Transpiled Depth, xi, 2q gates for the 6 qubit group = 20, 0.5, 15.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 7 qubit group = 27, 0.525
# Average Normalized Transpiled Depth, xi, 2q gates for the 7 qubit group = 27, 0.525, 21.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 8 qubit group = 34, 0.571
# Average Normalized Transpiled Depth, xi, 2q gates for the 8 qubit group = 34, 0.571, 28.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 9 qubit group = 42, 0.59
# Average Normalized Transpiled Depth, xi, 2q gates for the 9 qubit group = 42, 0.59, 36.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 10 qubit group = 51, 0.625
# Average Normalized Transpiled Depth, xi, 2q gates for the 10 qubit group = 51, 0.625, 45.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 11 qubit group = 61, 0.64
# Average Normalized Transpiled Depth, xi, 2q gates for the 11 qubit group = 61, 0.64, 55.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 12 qubit group = 72, 0.667
# Average Normalized Transpiled Depth, xi, 2q gates for the 12 qubit group = 72, 0.667, 66.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 13 qubit group = 84, 0.678
# Average Normalized Transpiled Depth, xi, 2q gates for the 13 qubit group = 84, 0.678, 78.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 14 qubit group = 97, 0.7
# Average Normalized Transpiled Depth, xi, 2q gates for the 14 qubit group = 97, 0.7, 91.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 15 qubit group = 111, 0.709
# Average Normalized Transpiled Depth, xi, 2q gates for the 15 qubit group = 111, 0.709, 105.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 16 qubit group = 126, 0.727
# Average Normalized Transpiled Depth, xi, 2q gates for the 16 qubit group = 126, 0.727, 120.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 17 qubit group = 143, 0.735
# Average Normalized Transpiled Depth, xi, 2q gates for the 17 qubit group = 143, 0.735, 136.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 18 qubit group = 159, 0.75
# Average Normalized Transpiled Depth, xi, 2q gates for the 18 qubit group = 159, 0.75, 153.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 19 qubit group = 178, 0.757
# Average Normalized Transpiled Depth, xi, 2q gates for the 19 qubit group = 178, 0.757, 171.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 20 qubit group = 197, 0.769
# Average Normalized Transpiled Depth, xi, 2q gates for the 20 qubit group = 197, 0.769, 190.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 21 qubit group = 217, 0.775
# Average Normalized Transpiled Depth, xi, 2q gates for the 21 qubit group = 217, 0.775, 210.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 22 qubit group = 238, 0.786
# Average Normalized Transpiled Depth, xi, 2q gates for the 22 qubit group = 238, 0.786, 231.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 23 qubit group = 260, 0.791
# Average Normalized Transpiled Depth, xi, 2q gates for the 23 qubit group = 260, 0.791, 253.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 1.0, 1.0
#
# ************
# Average Circuit Algorithmic Depth, xi for the 24 qubit group = 283, 0.8
# Average Normalized Transpiled Depth, xi, 2q gates for the 24 qubit group = 283, 0.8, 276.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.0, 0.014, 0.014 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ... execution complete at May 13, 2026 13:38:22 UTC in 0.374 secs
#
# Sample Circuit:
#      ╭───╮                                                                    »
# q0 : ┤ h ├──────●─────────────────────────────────────────────────────────────»
#      ├───┤      │                                                             »
# q1 : ┤ h ├──────┼─────────────●───────────────────────────────────────────────»
#      ├───┤      │             │                                               »
# q2 : ┤ h ├──────┼─────────────┼─────────────●─────────────────────────────────»
#      ├───┤      │             │             │                                 »
# q3 : ┤ h ├──────┼─────────────┼─────────────┼─────────────●───────────────────»
#      ├───┤      │             │             │             │                   »
# q4 : ┤ h ├──────┼─────────────┼─────────────┼─────────────┼────────────●──────»
#      ├───┤╭─────┴──────╮╭─────┴──────╮╭─────┴──────╮╭─────┴─────╮╭─────┴─────╮»
# q5 : ┤ x ├┤ r1(0.1963) ├┤ r1(0.3927) ├┤ r1(0.7854) ├┤ r1(1.571) ├┤ r1(3.142) ├»
#      ╰───╯╰────────────╯╰────────────╯╰────────────╯╰───────────╯╰───────────╯»
#
# ################################################################################
#
#                                                           ╭─────────────╮     »
# ─╳──╳─────────────────────────────────────────────────────┤ r1(-0.1963) ├─────»
#  │  │                                      ╭─────────────╮╰──────┬──────╯     »
# ─┼──┼───╳───╳──────────────────────────────┤ r1(-0.3927) ├───────┼────────────»
#  │  │   │   │               ╭─────────────╮╰──────┬──────╯       │            »
# ─┼──┼───┼───┼───────────────┤ r1(-0.7854) ├───────┼──────────────┼────────────»
#  │  │   │   │ ╭────────────╮╰──────┬──────╯       │              │       ╭───╮»
# ─┼──┼───╳───╳─┤ r1(-1.571) ├───────┼──────────────┼──────────────┼───────┤ h ├»
#  │  │ ╭───╮   ╰─────┬──────╯       │              │              │       ╰───╯»
# ─╳──╳─┤ h ├─────────●──────────────●──────────────●──────────────●────────────»
#       ╰───╯                                                                   »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#                              ╭─────────────╮                   ╭─────────────╮»
# ─────────────────────────────┤ r1(-0.3927) ├───────────────────┤ r1(-0.7854) ├»
#               ╭─────────────╮╰──────┬──────╯     ╭────────────╮╰──────┬──────╯»
# ──────────────┤ r1(-0.7854) ├───────┼────────────┤ r1(-1.571) ├───────┼───────»
# ╭────────────╮╰──────┬──────╯       │       ╭───╮╰─────┬──────╯       │       »
# ┤ r1(-1.571) ├───────┼──────────────┼───────┤ h ├──────●──────────────●───────»
# ╰─────┬──────╯       │              │       ╰───╯                             »
# ──────●──────────────●──────────────●─────────────────────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#      ╭────────────╮╭───╮
# ─────┤ r1(-1.571) ├┤ h ├
# ╭───╮╰─────┬──────╯╰───╯
# ┤ h ├──────●────────────
# ╰───╯
# ────────────────────────
#
# ────────────────────────
#
# ────────────────────────
#
# ────────────────────────

# %% [markdown]
# # Execute Benchmarks with Noise
# The next set of cells configures the benchmarks to execute on the density-matrix-cpu simulator where noise is simulated during execution.
# Noisy simulation is costly and hence we limit the number of qubits executed to only 10 here.
# The default noise model used sets a depolarization channel with a value 0.04 on all single-qubit operations.

# %%
# Noisy simulation settings (override app_args and exec_args for noisy execution)
app_args = dict(
    min_qubits = 2,
    max_qubits = 8,                     # execute fewer qubits with noise model
    skip_qubits = 1,
    max_circuits = 1,
    num_shots = 1000,
    api = "cudaq",
)

exec_args = dict(
    backend_id = "density-matrix-cpu",  # noisy simulation target
    hub = "", group = "", project = "",
    provider_backend = None,
    exec_options = {"noise_model": "default"},
)

# Add a suffix to data/image files to distinguish noisy results
from qedclib import metrics
metrics.data_suffix = "-mysystem-noisy"

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
from bernstein_vazirani import bv_benchmark
bv_benchmark.run(method=1, **app_args, **exec_args)
# Out:
# ... execution starting at May 13, 2026 13:38:24 UTC
# ************
# Creating [1] circuits with num_qubits = 3
# ************
# Creating [1] circuits with num_qubits = 4
# ************
# Creating [1] circuits with num_qubits = 5
# ************
# Creating [1] circuits with num_qubits = 6
# ************
# Creating [1] circuits with num_qubits = 7
# ************
# Creating [1] circuits with num_qubits = 8
# ... configure execution for target backend_id = density-matrix-cpu
# ************
# Average Circuit Algorithmic Depth, xi for the 3 qubit group = 5, 0.143
# Average Normalized Transpiled Depth, xi, 2q gates for the 3 qubit group = 5, 0.143, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.006, 0.006 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.845, 0.793
#
# ************
# Average Circuit Algorithmic Depth, xi for the 4 qubit group = 5, 0.111
# Average Normalized Transpiled Depth, xi, 2q gates for the 4 qubit group = 5, 0.111, 1.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.818, 0.792
#
# ************
# Average Circuit Algorithmic Depth, xi for the 5 qubit group = 5, 0.091
# Average Normalized Transpiled Depth, xi, 2q gates for the 5 qubit group = 5, 0.091, 1.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.006, 0.006 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.801, 0.788
#
# ************
# Average Circuit Algorithmic Depth, xi for the 6 qubit group = 5, 0.077
# Average Normalized Transpiled Depth, xi, 2q gates for the 6 qubit group = 5, 0.077, 1.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.071, 0.071 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.738, 0.73
#
# ************
# Average Circuit Algorithmic Depth, xi for the 7 qubit group = 7, 0.176
# Average Normalized Transpiled Depth, xi, 2q gates for the 7 qubit group = 7, 0.176, 3.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.235, 0.235 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.72, 0.716
#
# ************
# Average Circuit Algorithmic Depth, xi for the 8 qubit group = 7, 0.158
# Average Normalized Transpiled Depth, xi, 2q gates for the 8 qubit group = 7, 0.158, 3.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.625, 0.625 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.659, 0.656
#
# ... execution complete at May 13, 2026 13:38:25 UTC in 1.078 secs
#
# Sample Circuit:
#      ╭───╮╭───╮
# q0 : ┤ h ├┤ h ├──────────
#      ├───┤╰───╯     ╭───╮
# q1 : ┤ h ├───────●──┤ h ├
#      ├───┤       │  ├───┤
# q2 : ┤ h ├───────┼──┤ h ├
#      ├───┤       │  ├───┤
# q3 : ┤ h ├───────┼──┤ h ├
#      ├───┤       │  ├───┤
# q4 : ┤ h ├───────┼──┤ h ├
#      ├───┤╭───╮╭─┴─╮╰───╯
# q5 : ┤ h ├┤ z ├┤ x ├─────
#      ╰───╯╰───╯╰───╯

# %% [markdown]
# ### Hidden Shift

# %%
from hidden_shift import hs_benchmark
hs_benchmark.run(**app_args, **exec_args)
# Out:
# ... execution starting at May 13, 2026 13:38:26 UTC
# ************
# Creating [1] circuits with num_qubits = 2
# ************
# Creating [1] circuits with num_qubits = 4
# ************
# Creating [1] circuits with num_qubits = 6
# ************
# Creating [1] circuits with num_qubits = 8
# ... configure execution for target backend_id = density-matrix-cpu
# ************
# Average Circuit Algorithmic Depth, xi for the 2 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, xi, 2q gates for the 2 qubit group = 8, 0.2, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.008, 0.008 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.78, 0.707
#
# ************
# Average Circuit Algorithmic Depth, xi for the 4 qubit group = 10, 0.222
# Average Normalized Transpiled Depth, xi, 2q gates for the 4 qubit group = 10, 0.222, 4.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.082, 0.082 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.652, 0.629
#
# ************
# Average Circuit Algorithmic Depth, xi for the 6 qubit group = 12, 0.231
# Average Normalized Transpiled Depth, xi, 2q gates for the 6 qubit group = 12, 0.231, 6.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.112, 0.112 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.545, 0.538
#
# ************
# Average Circuit Algorithmic Depth, xi for the 8 qubit group = 14, 0.235
# Average Normalized Transpiled Depth, xi, 2q gates for the 8 qubit group = 14, 0.235, 8.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 1.004, 1.004 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.432, 0.43
#
# ... execution complete at May 13, 2026 13:38:27 UTC in 1.325 secs
#
# Sample Circuit:
#      ╭───╮     ╭───╮     ╭───╮
# q0 : ┤ h ├──●──┤ h ├──●──┤ h ├──────────
#      ├───┤╭─┴─╮├───┤╭─┴─╮├───┤
# q1 : ┤ h ├┤ z ├┤ h ├┤ z ├┤ h ├──────────
#      ├───┤╰───╯├───┤╰───╯├───┤
# q2 : ┤ h ├──●──┤ h ├──●──┤ h ├──────────
#      ├───┤╭─┴─╮├───┤╭─┴─╮├───┤
# q3 : ┤ h ├┤ z ├┤ h ├┤ z ├┤ h ├──────────
#      ├───┤╰───╯╰───╯├───┤╰───╯     ╭───╮
# q4 : ┤ h ├───────●──┤ h ├───────●──┤ h ├
#      ├───┤╭───╮╭─┴─╮├───┤╭───╮╭─┴─╮├───┤
# q5 : ┤ h ├┤ x ├┤ z ├┤ x ├┤ h ├┤ z ├┤ h ├
#      ╰───╯╰───╯╰───╯╰───╯╰───╯╰───╯╰───╯

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
from quantum_fourier_transform import qft_benchmark
qft_benchmark.run(method=1, **app_args, **exec_args)
# Out:
# ... execution starting at May 13, 2026 13:38:28 UTC
# ************
# Creating [1] circuits with num_qubits = 2
# ************
# Creating [1] circuits with num_qubits = 3
# ************
# Creating [1] circuits with num_qubits = 4
# ************
# Creating [1] circuits with num_qubits = 5
# ************
# Creating [1] circuits with num_qubits = 6
# ************
# Creating [1] circuits with num_qubits = 7
# ************
# Creating [1] circuits with num_qubits = 8
# ... configure execution for target backend_id = density-matrix-cpu
# ************
# Average Circuit Algorithmic Depth, xi for the 2 qubit group = 9, 0.182
# Average Normalized Transpiled Depth, xi, 2q gates for the 2 qubit group = 9, 0.182, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.846, 0.795
#
# ************
# Average Circuit Algorithmic Depth, xi for the 3 qubit group = 13, 0.333
# Average Normalized Transpiled Depth, xi, 2q gates for the 3 qubit group = 13, 0.333, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.771, 0.738
#
# ************
# Average Circuit Algorithmic Depth, xi for the 4 qubit group = 20, 0.414
# Average Normalized Transpiled Depth, xi, 2q gates for the 4 qubit group = 20, 0.414, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.715, 0.696
#
# ************
# Average Circuit Algorithmic Depth, xi for the 5 qubit group = 27, 0.5
# Average Normalized Transpiled Depth, xi, 2q gates for the 5 qubit group = 27, 0.5, 20.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.1, 0.1 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.648, 0.637
#
# ************
# Average Circuit Algorithmic Depth, xi for the 6 qubit group = 38, 0.545
# Average Normalized Transpiled Depth, xi, 2q gates for the 6 qubit group = 38, 0.545, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.179, 0.179 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.595, 0.589
#
# ************
# Average Circuit Algorithmic Depth, xi for the 7 qubit group = 51, 0.568
# Average Normalized Transpiled Depth, xi, 2q gates for the 7 qubit group = 51, 0.568, 42.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.416, 0.416 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.52, 0.516
#
# ************
# Average Circuit Algorithmic Depth, xi for the 8 qubit group = 65, 0.615
# Average Normalized Transpiled Depth, xi, 2q gates for the 8 qubit group = 65, 0.615, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 1.195, 1.195 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.489, 0.487
#
# ... execution complete at May 13, 2026 13:38:30 UTC in 2.031 secs
#
# Sample Circuit:
#      ╭───╮╭───────────╮     ╭────────────╮                  ╭────────────╮»
# q0 : ┤ h ├┤ r1(1.571) ├─────┤ r1(0.7854) ├──────────────────┤ r1(0.3927) ├»
#      ╰───╯╰─────┬─────╯╭───╮╰─────┬──────╯╭───────────╮     ╰─────┬──────╯»
# q1 : ───────────●──────┤ h ├──────┼───────┤ r1(1.571) ├───────────┼───────»
#                        ╰───╯      │       ╰─────┬─────╯╭───╮      │       »
# q2 : ─────────────────────────────●─────────────●──────┤ h ├──────┼───────»
#                                                        ╰───╯      │       »
# q3 : ─────────────────────────────────────────────────────────────●───────»
#                                                                           »
# q4 : ─────────────────────────────────────────────────────────────────────»
#      ╭───╮                                                                »
# q5 : ┤ x ├────────────────────────────────────────────────────────────────»
#      ╰───╯                                                                »
#
# ################################################################################
#
#                                 ╭────────────╮                            »
# ────────────────────────────────┤ r1(0.1963) ├────────────────────────────»
# ╭────────────╮                  ╰─────┬──────╯╭────────────╮              »
# ┤ r1(0.7854) ├────────────────────────┼───────┤ r1(0.3927) ├──────────────»
# ╰─────┬──────╯╭───────────╮           │       ╰─────┬──────╯╭────────────╮»
# ──────┼───────┤ r1(1.571) ├───────────┼─────────────┼───────┤ r1(0.7854) ├»
#       │       ╰─────┬─────╯╭───╮      │             │       ╰─────┬──────╯»
# ──────●─────────────●──────┤ h ├──────┼─────────────┼─────────────┼───────»
#                            ╰───╯      │             │             │       »
# ──────────────────────────────────────●─────────────●─────────────●───────»
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
#                                                                           »
#
# ################################################################################
#
#                   ╭─────────────╮╭─────────────╮                            »
# ──────────────────┤ r1(0.09817) ├┤ rz(0.09817) ├────────────────────────────»
#                   ╰──────┬──────╯├────────────┬╯╭────────────╮              »
# ─────────────────────────┼───────┤ r1(0.1963) ├─┤ rz(0.1963) ├──────────────»
#                          │       ╰─────┬──────╯ ├────────────┤╭────────────╮»
# ─────────────────────────┼─────────────┼────────┤ r1(0.3927) ├┤ rz(0.3927) ├»
# ╭───────────╮            │             │        ╰─────┬──────╯├────────────┤»
# ┤ r1(1.571) ├────────────┼─────────────┼──────────────┼───────┤ r1(0.7854) ├»
# ╰─────┬─────╯╭───╮       │             │              │       ╰─────┬──────╯»
# ──────●──────┤ h ├───────┼─────────────┼──────────────┼─────────────┼───────»
#              ╰───╯       │             │              │             │       »
# ─────────────────────────●─────────────●──────────────●─────────────●───────»
#                                                                             »
#
# ################################################################################
#
#                                                                        »
# ─────────────────────────────────────────╳──╳──────────────────────────»
#                                          │  │                          »
# ─────────────────────────────────────────┼──┼───╳───╳──────────────────»
#                                          │  │   │   │                  »
# ─────────────────────────────────────────┼──┼───┼───┼───────╳────────╳─»
# ╭────────────╮                           │  │   │   │       │        │ »
# ┤ rz(0.7854) ├───────────────────────────┼──┼───┼───┼───────╳────────╳─»
# ├───────────┬╯╭───────────╮              │  │   │   │ ╭────────────╮   »
# ┤ r1(1.571) ├─┤ rz(1.571) ├──────────────┼──┼───╳───╳─┤ r1(-1.571) ├───»
# ╰─────┬─────╯ ╰───┬───┬───╯╭───────────╮ │  │ ╭───╮   ╰─────┬──────╯   »
# ──────●───────────┤ h ├────┤ rz(3.142) ├─╳──╳─┤ h ├─────────●──────────»
#                   ╰───╯    ╰───────────╯      ╰───╯                    »
#
# ################################################################################
#
#                                              ╭──────────────╮     »
# ─────────────────────────────────────────────┤ r1(-0.09817) ├─────»
#                               ╭─────────────╮╰──────┬───────╯     »
# ──────────────────────────────┤ r1(-0.1963) ├───────┼─────────────»
#                ╭─────────────╮╰──────┬──────╯       │             »
# ───────────────┤ r1(-0.3927) ├───────┼──────────────┼─────────────»
# ╭─────────────╮╰──────┬──────╯       │              │             »
# ┤ r1(-0.7854) ├───────┼──────────────┼──────────────┼─────────────»
# ╰──────┬──────╯       │              │              │        ╭───╮»
# ───────┼──────────────┼──────────────┼──────────────┼────────┤ h ├»
#        │              │              │              │        ╰───╯»
# ───────●──────────────●──────────────●──────────────●─────────────»
#                                                                   »
#
# ################################################################################
#
#                                             ╭─────────────╮                   »
# ────────────────────────────────────────────┤ r1(-0.1963) ├───────────────────»
#                              ╭─────────────╮╰──────┬──────╯                   »
# ─────────────────────────────┤ r1(-0.3927) ├───────┼──────────────────────────»
#               ╭─────────────╮╰──────┬──────╯       │            ╭────────────╮»
# ──────────────┤ r1(-0.7854) ├───────┼──────────────┼────────────┤ r1(-1.571) ├»
# ╭────────────╮╰──────┬──────╯       │              │       ╭───╮╰─────┬──────╯»
# ┤ r1(-1.571) ├───────┼──────────────┼──────────────┼───────┤ h ├──────●───────»
# ╰─────┬──────╯       │              │              │       ╰───╯              »
# ──────●──────────────●──────────────●──────────────●──────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#                ╭─────────────╮                   ╭─────────────╮     »
# ───────────────┤ r1(-0.3927) ├───────────────────┤ r1(-0.7854) ├─────»
# ╭─────────────╮╰──────┬──────╯     ╭────────────╮╰──────┬──────╯╭───╮»
# ┤ r1(-0.7854) ├───────┼────────────┤ r1(-1.571) ├───────┼───────┤ h ├»
# ╰──────┬──────╯       │       ╭───╮╰─────┬──────╯       │       ╰───╯»
# ───────┼──────────────┼───────┤ h ├──────●──────────────●────────────»
#        │              │       ╰───╯                                  »
# ───────●──────────────●──────────────────────────────────────────────»
#                                                                      »
# ─────────────────────────────────────────────────────────────────────»
#                                                                      »
# ─────────────────────────────────────────────────────────────────────»
#                                                                      »
#
# ################################################################################
#
# ╭────────────╮╭───╮
# ┤ r1(-1.571) ├┤ h ├
# ╰─────┬──────╯╰───╯
# ──────●────────────
#
# ───────────────────
#
# ───────────────────
#
# ───────────────────
#
# ───────────────────

# %% [markdown]
# ### Quantum Phase Estimation

# %%
from phase_estimation import pe_benchmark
pe_benchmark.run(**app_args, **exec_args)
# Out:
# ... execution starting at May 13, 2026 13:38:32 UTC
# ************
# Creating [1] circuits with num_qubits = 3
# ************
# Creating [1] circuits with num_qubits = 4
# ************
# Creating [1] circuits with num_qubits = 5
# ************
# Creating [1] circuits with num_qubits = 6
# ************
# Creating [1] circuits with num_qubits = 7
# ************
# Creating [1] circuits with num_qubits = 8
# ... configure execution for target backend_id = density-matrix-cpu
# ************
# Average Circuit Algorithmic Depth, xi for the 3 qubit group = 8, 0.3
# Average Normalized Transpiled Depth, xi, 2q gates for the 3 qubit group = 8, 0.3, 3.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.873, 0.831
#
# ************
# Average Circuit Algorithmic Depth, xi for the 4 qubit group = 11, 0.4
# Average Normalized Transpiled Depth, xi, 2q gates for the 4 qubit group = 11, 0.4, 6.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.822, 0.797
#
# ************
# Average Circuit Algorithmic Depth, xi for the 5 qubit group = 15, 0.435
# Average Normalized Transpiled Depth, xi, 2q gates for the 5 qubit group = 15, 0.435, 10.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.03, 0.03 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.792, 0.778
#
# ************
# Average Circuit Algorithmic Depth, xi for the 6 qubit group = 20, 0.5
# Average Normalized Transpiled Depth, xi, 2q gates for the 6 qubit group = 20, 0.5, 15.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.094, 0.094 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.73, 0.721
#
# ************
# Average Circuit Algorithmic Depth, xi for the 7 qubit group = 27, 0.525
# Average Normalized Transpiled Depth, xi, 2q gates for the 7 qubit group = 27, 0.525, 21.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.234, 0.234 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.73, 0.726
#
# ************
# Average Circuit Algorithmic Depth, xi for the 8 qubit group = 34, 0.571
# Average Normalized Transpiled Depth, xi, 2q gates for the 8 qubit group = 34, 0.571, 28.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.646, 0.646 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.666, 0.663
#
# ... execution complete at May 13, 2026 13:38:33 UTC in 1.144 secs
#
# Sample Circuit:
#      ╭───╮                                                                    »
# q0 : ┤ h ├──────●─────────────────────────────────────────────────────────────»
#      ├───┤      │                                                             »
# q1 : ┤ h ├──────┼─────────────●───────────────────────────────────────────────»
#      ├───┤      │             │                                               »
# q2 : ┤ h ├──────┼─────────────┼─────────────●─────────────────────────────────»
#      ├───┤      │             │             │                                 »
# q3 : ┤ h ├──────┼─────────────┼─────────────┼─────────────●───────────────────»
#      ├───┤      │             │             │             │                   »
# q4 : ┤ h ├──────┼─────────────┼─────────────┼─────────────┼────────────●──────»
#      ├───┤╭─────┴──────╮╭─────┴──────╮╭─────┴──────╮╭─────┴─────╮╭─────┴─────╮»
# q5 : ┤ x ├┤ r1(0.1963) ├┤ r1(0.3927) ├┤ r1(0.7854) ├┤ r1(1.571) ├┤ r1(3.142) ├»
#      ╰───╯╰────────────╯╰────────────╯╰────────────╯╰───────────╯╰───────────╯»
#
# ################################################################################
#
#                                                           ╭─────────────╮     »
# ─╳──╳─────────────────────────────────────────────────────┤ r1(-0.1963) ├─────»
#  │  │                                      ╭─────────────╮╰──────┬──────╯     »
# ─┼──┼───╳───╳──────────────────────────────┤ r1(-0.3927) ├───────┼────────────»
#  │  │   │   │               ╭─────────────╮╰──────┬──────╯       │            »
# ─┼──┼───┼───┼───────────────┤ r1(-0.7854) ├───────┼──────────────┼────────────»
#  │  │   │   │ ╭────────────╮╰──────┬──────╯       │              │       ╭───╮»
# ─┼──┼───╳───╳─┤ r1(-1.571) ├───────┼──────────────┼──────────────┼───────┤ h ├»
#  │  │ ╭───╮   ╰─────┬──────╯       │              │              │       ╰───╯»
# ─╳──╳─┤ h ├─────────●──────────────●──────────────●──────────────●────────────»
#       ╰───╯                                                                   »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#                              ╭─────────────╮                   ╭─────────────╮»
# ─────────────────────────────┤ r1(-0.3927) ├───────────────────┤ r1(-0.7854) ├»
#               ╭─────────────╮╰──────┬──────╯     ╭────────────╮╰──────┬──────╯»
# ──────────────┤ r1(-0.7854) ├───────┼────────────┤ r1(-1.571) ├───────┼───────»
# ╭────────────╮╰──────┬──────╯       │       ╭───╮╰─────┬──────╯       │       »
# ┤ r1(-1.571) ├───────┼──────────────┼───────┤ h ├──────●──────────────●───────»
# ╰─────┬──────╯       │              │       ╰───╯                             »
# ──────●──────────────●──────────────●─────────────────────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#      ╭────────────╮╭───╮
# ─────┤ r1(-1.571) ├┤ h ├
# ╭───╮╰─────┬──────╯╰───╯
# ┤ h ├──────●────────────
# ╰───╯
# ────────────────────────
#
# ────────────────────────
#
# ────────────────────────
#
# ────────────────────────

# %%
import cudaq
print(cudaq.__version__)
# Out:
# CUDA-Q Version amd64-cu12-0.13.0 (https://github.com/NVIDIA/cuda-quantum b66c5bb7fd8c08e5014e2f03e97e7b0e92691650)

# %%
# Generate a volumetric positioning plot showing combined results from all benchmarks executed above.
from qedclib import metrics

# Options for configuring the plot
# metrics.depth_base = 2
# metrics.QV = 0
# apps = [ "Hidden Shift", "Quantum Fourier Transform (1)", "Phase Estimation" ]
# backend_id='nvidia'

metrics.plot_all_app_metrics(exec_args["backend_id"], do_all_plots=False, include_apps=None)

# %% [markdown]
# ### Combined Benchmark Results
