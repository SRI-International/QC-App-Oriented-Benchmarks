# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - CUDA Quantum Version
# The notebook contains a suite of application-oriented benchmarks for the CUDA Quantum API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one benchmark program.

# %%
# Specify the parameters for the benchmark
min_qubits=2
max_qubits=24
skip_qubits=1
max_circuits=1
num_shots=1000

# Set these default parameters
hub=""; group=""; project=""
provider_backend = None
exec_options = {}

# For CUDA Quantum, specify this API option
api="cudaq"

# Select the backend on which the benchmark program will execute
backend_id="nvidia"
#backend_id="density-matrix-cpu"    # for noisy simulation

# # Uncomment these lines to add a suffix to your backend_id and data/image files
# import _common.metrics as metrics
# metrics.data_suffix = "-mysystem"

# OPTIONS (for additional features): 
# import sys
# sys.path.insert(1, "_common/cudaq")

# # Uncomment these lines to add a default noise model for execution
# import execute
# #execute.set_noise_model(noise_model = None)      # for no noise
# execute.set_default_noise_model()                # for simple default noise model

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
from bernstein_vazirani import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options,
                api=api)
# Out:
# Bernstein-Vazirani (1) Benchmark Program - Qiskit
# ... execution starting at Jan 25, 2026 20:24:56 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 5, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 5, 0.143, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.173, 0.172 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 5, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 5, 0.111, 1.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 5, 0.091
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 5, 0.091, 1.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 7, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 7, 0.2, 3.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 6, 0.125
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 6, 0.125, 2.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 8, 0.2, 4.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 6, 0.1
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 6, 0.1, 2.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 7, 0.13
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 7, 0.13, 3.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 9, 0.185
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 9, 0.185, 5.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 7, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 7, 0.111, 3.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 10, 0.188
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 10, 0.188, 6.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 11, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 11, 0.2, 7.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 9, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 9, 0.143, 5.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 14, 0.22
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 14, 0.22, 9.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 14, 0.209
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 14, 0.209, 9.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 10, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 10, 0.143, 6.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 19
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 12, 0.174
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 12, 0.174, 8.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 13, 0.184
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 13, 0.184, 9.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 21
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 13, 0.176
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 13, 0.176, 9.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 14, 0.185
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 14, 0.185, 10.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 18, 0.22
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 18, 0.22, 13.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 13, 0.158
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 13, 0.158, 9.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.0, 0.008, 0.008 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ... execution complete at Jan 25, 2026 20:24:57 UTC in 0.269 secs
#
# Sample Circuit:
#      ╭───╮                    ╭───╮
# q0 : ┤ h ├─────────────────●──┤ h ├
#      ├───┤                 │  ├───┤
# q1 : ┤ h ├─────────────────┼──┤ h ├
#      ├───┤                 │  ├───┤
# q2 : ┤ h ├─────────────────┼──┤ h ├
#      ├───┤                 │  ├───┤
# q3 : ┤ h ├────────────●────┼──┤ h ├
#      ├───┤            │    │  ├───┤
# q4 : ┤ h ├───────●────┼────┼──┤ h ├
#      ├───┤╭───╮╭─┴─╮╭─┴─╮╭─┴─╮╰───╯
# q5 : ┤ h ├┤ z ├┤ x ├┤ x ├┤ x ├─────
#      ╰───╯╰───╯╰───╯╰───╯╰───╯

# %% [markdown]
# ### Hidden Shift

# %%
from hidden_shift import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options,
                api=api)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Jan 25, 2026 20:24:58 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 2
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.2, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.062, 0.062 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 10, 0.222
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 10, 0.222, 4.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 12, 0.231
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 12, 0.231, 6.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 14, 0.222
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 14, 0.222, 8.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 16, 0.227
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 16, 0.227, 10.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 18, 0.222
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 18, 0.222, 12.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 20, 0.212
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 20, 0.212, 14.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 22, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 22, 0.2, 16.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 24, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 24, 0.2, 18.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 26, 0.213
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 26, 0.213, 20.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 28, 0.204
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 28, 0.204, 22.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.0, 0.002, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 30, 0.203
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 30, 0.203, 24.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ... execution complete at Jan 25, 2026 20:24:58 UTC in 0.119 secs
#
# Sample Circuit:
#      ╭───╮     ╭───╮     ╭───╮
# q0 : ┤ h ├──●──┤ h ├──●──┤ h ├──────────
#      ├───┤╭─┴─╮├───┤╭─┴─╮├───┤
# q1 : ┤ h ├┤ z ├┤ h ├┤ z ├┤ h ├──────────
#      ├───┤╰───╯├───┤╰───╯├───┤
# q2 : ┤ h ├──●──┤ h ├──●──┤ h ├──────────
#      ├───┤╭─┴─╮├───┤╭─┴─╮├───┤
# q3 : ┤ h ├┤ z ├┤ h ├┤ z ├┤ h ├──────────
#      ├───┤╰───╯╰───╯├───┤╰───╯     ╭───╮
# q4 : ┤ h ├───────●──┤ h ├───────●──┤ h ├
#      ├───┤╭───╮╭─┴─╮├───┤╭───╮╭─┴─╮├───┤
# q5 : ┤ h ├┤ x ├┤ z ├┤ x ├┤ h ├┤ z ├┤ h ├
#      ╰───╯╰───╯╰───╯╰───╯╰───╯╰───╯╰───╯

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
from quantum_fourier_transform import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options,
                api=api)
# Out:
# Quantum Fourier Transform (1) Benchmark Program - Qiskit
# ... execution starting at Jan 25, 2026 20:25:00 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 2
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.222
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.222, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.071, 0.071 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 12, 0.375
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 12, 0.375, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 19, 0.48
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 19, 0.48, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 27, 0.556
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 27, 0.556, 20.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 37, 0.612
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 37, 0.612, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 50, 0.618
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 50, 0.618, 42.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 63, 0.675
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 63, 0.675, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 79, 0.706
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 79, 0.706, 72.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 97, 0.732
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 97, 0.732, 90.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 118, 0.748
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 118, 0.748, 110.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 140, 0.763
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 140, 0.763, 132.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 164, 0.78
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 164, 0.78, 156.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 190, 0.795
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 190, 0.795, 182.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 218, 0.805
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 218, 0.805, 210.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.0, 0.003, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 248, 0.814
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 248, 0.814, 240.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 280, 0.822
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 280, 0.822, 272.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.0, 0.004, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 314, 0.832
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 314, 0.832, 306.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 19
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 350, 0.84
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 350, 0.84, 342.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.0, 0.005, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 388, 0.848
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 388, 0.848, 380.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 21
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 428, 0.855
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 428, 0.855, 420.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 470, 0.86
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 470, 0.86, 462.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.0, 0.006, 0.006 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 514, 0.866
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 514, 0.866, 506.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.0, 0.007, 0.007 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 560, 0.872
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 560, 0.872, 552.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.0, 0.02, 0.019 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ... execution complete at Jan 25, 2026 20:25:00 UTC in 0.213 secs
#
# Sample Circuit:
#      ╭───╮╭───────────╮     ╭────────────╮                  ╭────────────╮»
# q0 : ┤ h ├┤ r1(1.571) ├─────┤ r1(0.7854) ├──────────────────┤ r1(0.3927) ├»
#      ╰───╯╰─────┬─────╯╭───╮╰─────┬──────╯╭───────────╮     ╰─────┬──────╯»
# q1 : ───────────●──────┤ h ├──────┼───────┤ r1(1.571) ├───────────┼───────»
#                        ╰───╯      │       ╰─────┬─────╯╭───╮      │       »
# q2 : ─────────────────────────────●─────────────●──────┤ h ├──────┼───────»
#                                                        ╰───╯      │       »
# q3 : ─────────────────────────────────────────────────────────────●───────»
#                                                                           »
# q4 : ─────────────────────────────────────────────────────────────────────»
#      ╭───╮                                                                »
# q5 : ┤ x ├────────────────────────────────────────────────────────────────»
#      ╰───╯                                                                »
#
# ################################################################################
#
#                                 ╭────────────╮                            »
# ────────────────────────────────┤ r1(0.1963) ├────────────────────────────»
# ╭────────────╮                  ╰─────┬──────╯╭────────────╮              »
# ┤ r1(0.7854) ├────────────────────────┼───────┤ r1(0.3927) ├──────────────»
# ╰─────┬──────╯╭───────────╮           │       ╰─────┬──────╯╭────────────╮»
# ──────┼───────┤ r1(1.571) ├───────────┼─────────────┼───────┤ r1(0.7854) ├»
#       │       ╰─────┬─────╯╭───╮      │             │       ╰─────┬──────╯»
# ──────●─────────────●──────┤ h ├──────┼─────────────┼─────────────┼───────»
#                            ╰───╯      │             │             │       »
# ──────────────────────────────────────●─────────────●─────────────●───────»
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
#                                                                           »
#
# ################################################################################
#
#                   ╭─────────────╮╭─────────────╮                            »
# ──────────────────┤ r1(0.09817) ├┤ rz(0.09817) ├────────────────────────────»
#                   ╰──────┬──────╯├────────────┬╯╭────────────╮              »
# ─────────────────────────┼───────┤ r1(0.1963) ├─┤ rz(0.1963) ├──────────────»
#                          │       ╰─────┬──────╯ ├────────────┤╭────────────╮»
# ─────────────────────────┼─────────────┼────────┤ r1(0.3927) ├┤ rz(0.3927) ├»
# ╭───────────╮            │             │        ╰─────┬──────╯├────────────┤»
# ┤ r1(1.571) ├────────────┼─────────────┼──────────────┼───────┤ r1(0.7854) ├»
# ╰─────┬─────╯╭───╮       │             │              │       ╰─────┬──────╯»
# ──────●──────┤ h ├───────┼─────────────┼──────────────┼─────────────┼───────»
#              ╰───╯       │             │              │             │       »
# ─────────────────────────●─────────────●──────────────●─────────────●───────»
#                                                                             »
#
# ################################################################################
#
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
# ╭────────────╮                                             ╭─────────────╮»
# ┤ rz(0.7854) ├─────────────────────────────────────────────┤ r1(-0.7854) ├»
# ├───────────┬╯╭───────────╮                  ╭────────────╮╰──────┬──────╯»
# ┤ r1(1.571) ├─┤ rz(1.571) ├──────────────────┤ r1(-1.571) ├───────┼───────»
# ╰─────┬─────╯ ╰───┬───┬───╯╭───────────╮╭───╮╰─────┬──────╯       │       »
# ──────●───────────┤ h ├────┤ rz(3.142) ├┤ h ├──────●──────────────●───────»
#                   ╰───╯    ╰───────────╯╰───╯                             »
#
# ################################################################################
#
#                               ╭──────────────╮                   »
# ──────────────────────────────┤ r1(-0.09817) ├───────────────────»
#                ╭─────────────╮╰──────┬───────╯                   »
# ───────────────┤ r1(-0.1963) ├───────┼───────────────────────────»
# ╭─────────────╮╰──────┬──────╯       │                           »
# ┤ r1(-0.3927) ├───────┼──────────────┼───────────────────────────»
# ╰──────┬──────╯       │              │             ╭────────────╮»
# ───────┼──────────────┼──────────────┼─────────────┤ r1(-1.571) ├»
#        │              │              │        ╭───╮╰─────┬──────╯»
# ───────┼──────────────┼──────────────┼────────┤ h ├──────●───────»
#        │              │              │        ╰───╯              »
# ───────●──────────────●──────────────●───────────────────────────»
#                                                                  »
#
# ################################################################################
#
#                               ╭─────────────╮                   »
# ──────────────────────────────┤ r1(-0.1963) ├───────────────────»
#                ╭─────────────╮╰──────┬──────╯                   »
# ───────────────┤ r1(-0.3927) ├───────┼──────────────────────────»
# ╭─────────────╮╰──────┬──────╯       │            ╭────────────╮»
# ┤ r1(-0.7854) ├───────┼──────────────┼────────────┤ r1(-1.571) ├»
# ╰──────┬──────╯       │              │       ╭───╮╰─────┬──────╯»
# ───────┼──────────────┼──────────────┼───────┤ h ├──────●───────»
#        │              │              │       ╰───╯              »
# ───────●──────────────●──────────────●──────────────────────────»
#                                                                 »
# ────────────────────────────────────────────────────────────────»
#                                                                 »
#
# ################################################################################
#
#                ╭─────────────╮                   ╭─────────────╮     »
# ───────────────┤ r1(-0.3927) ├───────────────────┤ r1(-0.7854) ├─────»
# ╭─────────────╮╰──────┬──────╯     ╭────────────╮╰──────┬──────╯╭───╮»
# ┤ r1(-0.7854) ├───────┼────────────┤ r1(-1.571) ├───────┼───────┤ h ├»
# ╰──────┬──────╯       │       ╭───╮╰─────┬──────╯       │       ╰───╯»
# ───────┼──────────────┼───────┤ h ├──────●──────────────●────────────»
#        │              │       ╰───╯                                  »
# ───────●──────────────●──────────────────────────────────────────────»
#                                                                      »
# ─────────────────────────────────────────────────────────────────────»
#                                                                      »
# ─────────────────────────────────────────────────────────────────────»
#                                                                      »
#
# ################################################################################
#
# ╭────────────╮╭───╮
# ┤ r1(-1.571) ├┤ h ├
# ╰─────┬──────╯╰───╯
# ──────●────────────
#
# ───────────────────
#
# ───────────────────
#
# ───────────────────
#
# ───────────────────

# %% [markdown]
# ### Quantum Phase Estimation

# %%
from phase_estimation import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options,
                api=api)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Jan 25, 2026 20:25:01 UTC
# ... configure execution for target backend_id = nvidia
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 8, 0.3
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 8, 0.3, 3.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.073, 0.072 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 11, 0.4
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 11, 0.4, 6.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 15, 0.435
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 15, 0.435, 10.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 20, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 20, 0.5, 15.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 27, 0.525
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 27, 0.525, 21.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 34, 0.571
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 34, 0.571, 28.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 9
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 42, 0.59
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 42, 0.59, 36.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 10
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 51, 0.625
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 51, 0.625, 45.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 11
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 61, 0.64
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 61, 0.64, 55.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 72, 0.667
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 72, 0.667, 66.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 13
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 13 qubit group = 84, 0.678
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 13 qubit group = 84, 0.678, 78.0
# Average Creation, Elapsed, Execution Time for the 13 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 13 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 14 qubit group = 97, 0.7
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 14 qubit group = 97, 0.7, 91.0
# Average Creation, Elapsed, Execution Time for the 14 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 14 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 15
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 15 qubit group = 111, 0.709
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 15 qubit group = 111, 0.709, 105.0
# Average Creation, Elapsed, Execution Time for the 15 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 15 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 16
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 16 qubit group = 126, 0.727
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 16 qubit group = 126, 0.727, 120.0
# Average Creation, Elapsed, Execution Time for the 16 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 16 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 17 qubit group = 143, 0.735
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 17 qubit group = 143, 0.735, 136.0
# Average Creation, Elapsed, Execution Time for the 17 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 17 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 18
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 18 qubit group = 159, 0.75
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 18 qubit group = 159, 0.75, 153.0
# Average Creation, Elapsed, Execution Time for the 18 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 18 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 19
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 19 qubit group = 178, 0.757
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 19 qubit group = 178, 0.757, 171.0
# Average Creation, Elapsed, Execution Time for the 19 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 19 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 20
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 20 qubit group = 197, 0.769
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 20 qubit group = 197, 0.769, 190.0
# Average Creation, Elapsed, Execution Time for the 20 qubit group = 0.0, 0.003, 0.003 secs
# Average Hellinger, Normalized Fidelity for the 20 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 21
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 21 qubit group = 217, 0.775
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 21 qubit group = 217, 0.775, 210.0
# Average Creation, Elapsed, Execution Time for the 21 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 21 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 22 qubit group = 238, 0.786
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 22 qubit group = 238, 0.786, 231.0
# Average Creation, Elapsed, Execution Time for the 22 qubit group = 0.0, 0.004, 0.004 secs
# Average Hellinger, Normalized Fidelity for the 22 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 23 qubit group = 260, 0.791
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 23 qubit group = 260, 0.791, 253.0
# Average Creation, Elapsed, Execution Time for the 23 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 23 qubit group = 1.0, 1.0
#
# ************
# Executing [1] circuits with num_qubits = 24
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 24 qubit group = 283, 0.8
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 24 qubit group = 283, 0.8, 276.0
# Average Creation, Elapsed, Execution Time for the 24 qubit group = 0.0, 0.015, 0.014 secs
# Average Hellinger, Normalized Fidelity for the 24 qubit group = 1.0, 1.0
#
# ... execution complete at Jan 25, 2026 20:25:02 UTC in 0.245 secs
#
# Sample Circuit:
#      ╭───╮                                                                    »
# q0 : ┤ h ├──────●─────────────────────────────────────────────────────────────»
#      ├───┤      │                                                             »
# q1 : ┤ h ├──────┼─────────────●───────────────────────────────────────────────»
#      ├───┤      │             │                                               »
# q2 : ┤ h ├──────┼─────────────┼─────────────●─────────────────────────────────»
#      ├───┤      │             │             │                                 »
# q3 : ┤ h ├──────┼─────────────┼─────────────┼─────────────●───────────────────»
#      ├───┤      │             │             │             │                   »
# q4 : ┤ h ├──────┼─────────────┼─────────────┼─────────────┼────────────●──────»
#      ├───┤╭─────┴──────╮╭─────┴──────╮╭─────┴──────╮╭─────┴─────╮╭─────┴─────╮»
# q5 : ┤ x ├┤ r1(0.1963) ├┤ r1(0.3927) ├┤ r1(0.7854) ├┤ r1(1.571) ├┤ r1(3.142) ├»
#      ╰───╯╰────────────╯╰────────────╯╰────────────╯╰───────────╯╰───────────╯»
#
# ################################################################################
#
#                                                           ╭─────────────╮     »
# ─╳──╳─────────────────────────────────────────────────────┤ r1(-0.1963) ├─────»
#  │  │                                      ╭─────────────╮╰──────┬──────╯     »
# ─┼──┼───╳───╳──────────────────────────────┤ r1(-0.3927) ├───────┼────────────»
#  │  │   │   │               ╭─────────────╮╰──────┬──────╯       │            »
# ─┼──┼───┼───┼───────────────┤ r1(-0.7854) ├───────┼──────────────┼────────────»
#  │  │   │   │ ╭────────────╮╰──────┬──────╯       │              │       ╭───╮»
# ─┼──┼───╳───╳─┤ r1(-1.571) ├───────┼──────────────┼──────────────┼───────┤ h ├»
#  │  │ ╭───╮   ╰─────┬──────╯       │              │              │       ╰───╯»
# ─╳──╳─┤ h ├─────────●──────────────●──────────────●──────────────●────────────»
#       ╰───╯                                                                   »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#                              ╭─────────────╮                   ╭─────────────╮»
# ─────────────────────────────┤ r1(-0.3927) ├───────────────────┤ r1(-0.7854) ├»
#               ╭─────────────╮╰──────┬──────╯     ╭────────────╮╰──────┬──────╯»
# ──────────────┤ r1(-0.7854) ├───────┼────────────┤ r1(-1.571) ├───────┼───────»
# ╭────────────╮╰──────┬──────╯       │       ╭───╮╰─────┬──────╯       │       »
# ┤ r1(-1.571) ├───────┼──────────────┼───────┤ h ├──────●──────────────●───────»
# ╰─────┬──────╯       │              │       ╰───╯                             »
# ──────●──────────────●──────────────●─────────────────────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#      ╭────────────╮╭───╮
# ─────┤ r1(-1.571) ├┤ h ├
# ╭───╮╰─────┬──────╯╰───╯
# ┤ h ├──────●────────────
# ╰───╯
# ────────────────────────
#
# ────────────────────────
#
# ────────────────────────
#
# ────────────────────────

# %% [markdown]
# # Execute Benchmarks with Noise
# The next set of cells configures the benchmarks to execute on the density-matrix-cpu simulator where noise is simulated during execution.
# Noisy simulation is costly and hence we limit the number of qubits executed to only 10 here.
# The default noise model used sets a depolarization channel with a value 0.04 on all single-qubit operations.

# %%
# Specify the parameters for the benchmark
min_qubits=2
max_qubits=8                        # execute fewer qubits with noise model
skip_qubits=1
max_circuits=1
num_shots=1000

# Set these default parameters
hub=""; group=""; project=""
provider_backend = None
exec_options = {}

# For CUDA Quantum, specify this API option
api="cudaq"

# For noisy simulation, use this target
backend_id="density-matrix-cpu"

# OPTIONS: updated for running with noise
import sys
sys.path.insert(1, "_common")
sys.path.insert(1, "_common/cudaq")

# Uncomment these lines to add a suffix to your backend_id and data/image files
import metrics
metrics.data_suffix = "-mysystem-noisy"

# Uncomment these lines to add a default noise model for execution
import execute
execute.set_default_noise_model()                # for simple default noise model

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
from bernstein_vazirani import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options,
                api=api)
# Out:
# Bernstein-Vazirani (1) Benchmark Program - Qiskit
# ... execution starting at Jan 25, 2026 20:25:03 UTC
# ... configure execution for target backend_id = density-matrix-cpu
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 5, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 5, 0.143, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.09, 0.09 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.844, 0.792
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 5, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 5, 0.111, 1.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.824, 0.799
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 5, 0.091
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 5, 0.091, 1.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.005, 0.005 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.774, 0.759
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 5, 0.077
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 5, 0.077, 1.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.023, 0.023 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.748, 0.74
#
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 7, 0.176
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 7, 0.176, 3.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.114, 0.114 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.701, 0.696
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 7, 0.158
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 7, 0.158, 3.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.439, 0.439 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.678, 0.675
#
# ... execution complete at Jan 25, 2026 20:25:04 UTC in 0.678 secs
#
# Sample Circuit:
#      ╭───╮╭───╮
# q0 : ┤ h ├┤ h ├──────────
#      ├───┤╰───╯     ╭───╮
# q1 : ┤ h ├───────●──┤ h ├
#      ├───┤       │  ├───┤
# q2 : ┤ h ├───────┼──┤ h ├
#      ├───┤       │  ├───┤
# q3 : ┤ h ├───────┼──┤ h ├
#      ├───┤       │  ├───┤
# q4 : ┤ h ├───────┼──┤ h ├
#      ├───┤╭───╮╭─┴─╮╰───╯
# q5 : ┤ h ├┤ z ├┤ x ├─────
#      ╰───╯╰───╯╰───╯

# %% [markdown]
# ### Hidden Shift

# %%
from hidden_shift import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options,
                api=api)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Jan 25, 2026 20:25:05 UTC
# ... configure execution for target backend_id = density-matrix-cpu
# ************
# Executing [1] circuits with num_qubits = 2
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.2, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.095, 0.095 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.77, 0.693
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 10, 0.222
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 10, 0.222, 4.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.015, 0.015 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.689, 0.668
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 12, 0.231
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 12, 0.231, 6.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.037, 0.037 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.534, 0.527
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 14, 0.235
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 14, 0.235, 8.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.679, 0.679 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.469, 0.467
#
# ... execution complete at Jan 25, 2026 20:25:05 UTC in 0.83 secs
#
# Sample Circuit:
#      ╭───╮     ╭───╮     ╭───╮
# q0 : ┤ h ├──●──┤ h ├──●──┤ h ├──────────
#      ├───┤╭─┴─╮├───┤╭─┴─╮├───┤
# q1 : ┤ h ├┤ z ├┤ h ├┤ z ├┤ h ├──────────
#      ├───┤╰───╯├───┤╰───╯├───┤
# q2 : ┤ h ├──●──┤ h ├──●──┤ h ├──────────
#      ├───┤╭─┴─╮├───┤╭─┴─╮├───┤
# q3 : ┤ h ├┤ z ├┤ h ├┤ z ├┤ h ├──────────
#      ├───┤╰───╯╰───╯├───┤╰───╯     ╭───╮
# q4 : ┤ h ├───────●──┤ h ├───────●──┤ h ├
#      ├───┤╭───╮╭─┴─╮├───┤╭───╮╭─┴─╮├───┤
# q5 : ┤ h ├┤ x ├┤ z ├┤ x ├┤ h ├┤ z ├┤ h ├
#      ╰───╯╰───╯╰───╯╰───╯╰───╯╰───╯╰───╯

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
from quantum_fourier_transform import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options,
                api=api)
# Out:
# Quantum Fourier Transform (1) Benchmark Program - Qiskit
# ... execution starting at Jan 25, 2026 20:25:06 UTC
# ... configure execution for target backend_id = density-matrix-cpu
# ************
# Executing [1] circuits with num_qubits = 2
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 9, 0.182
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 9, 0.182, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.0, 0.089, 0.089 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.845, 0.793
#
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 13, 0.333
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 13, 0.333, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.776, 0.744
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 20, 0.414
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 20, 0.414, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.707, 0.687
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 27, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 27, 0.5, 20.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.008, 0.008 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.667, 0.656
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 38, 0.545
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 38, 0.545, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.038, 0.038 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.604, 0.598
#
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 51, 0.568
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 51, 0.568, 42.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.219, 0.219 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.508, 0.504
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 65, 0.615
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 65, 0.615, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.741, 0.74 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.499, 0.497
#
# ... execution complete at Jan 25, 2026 20:25:08 UTC in 1.103 secs
#
# Sample Circuit:
#      ╭───╮╭───────────╮     ╭────────────╮                  ╭────────────╮»
# q0 : ┤ h ├┤ r1(1.571) ├─────┤ r1(0.7854) ├──────────────────┤ r1(0.3927) ├»
#      ╰───╯╰─────┬─────╯╭───╮╰─────┬──────╯╭───────────╮     ╰─────┬──────╯»
# q1 : ───────────●──────┤ h ├──────┼───────┤ r1(1.571) ├───────────┼───────»
#                        ╰───╯      │       ╰─────┬─────╯╭───╮      │       »
# q2 : ─────────────────────────────●─────────────●──────┤ h ├──────┼───────»
#                                                        ╰───╯      │       »
# q3 : ─────────────────────────────────────────────────────────────●───────»
#                                                                           »
# q4 : ─────────────────────────────────────────────────────────────────────»
#      ╭───╮                                                                »
# q5 : ┤ x ├────────────────────────────────────────────────────────────────»
#      ╰───╯                                                                »
#
# ################################################################################
#
#                                 ╭────────────╮                            »
# ────────────────────────────────┤ r1(0.1963) ├────────────────────────────»
# ╭────────────╮                  ╰─────┬──────╯╭────────────╮              »
# ┤ r1(0.7854) ├────────────────────────┼───────┤ r1(0.3927) ├──────────────»
# ╰─────┬──────╯╭───────────╮           │       ╰─────┬──────╯╭────────────╮»
# ──────┼───────┤ r1(1.571) ├───────────┼─────────────┼───────┤ r1(0.7854) ├»
#       │       ╰─────┬─────╯╭───╮      │             │       ╰─────┬──────╯»
# ──────●─────────────●──────┤ h ├──────┼─────────────┼─────────────┼───────»
#                            ╰───╯      │             │             │       »
# ──────────────────────────────────────●─────────────●─────────────●───────»
#                                                                           »
# ──────────────────────────────────────────────────────────────────────────»
#                                                                           »
#
# ################################################################################
#
#                   ╭─────────────╮╭─────────────╮                            »
# ──────────────────┤ r1(0.09817) ├┤ rz(0.09817) ├────────────────────────────»
#                   ╰──────┬──────╯├────────────┬╯╭────────────╮              »
# ─────────────────────────┼───────┤ r1(0.1963) ├─┤ rz(0.1963) ├──────────────»
#                          │       ╰─────┬──────╯ ├────────────┤╭────────────╮»
# ─────────────────────────┼─────────────┼────────┤ r1(0.3927) ├┤ rz(0.3927) ├»
# ╭───────────╮            │             │        ╰─────┬──────╯├────────────┤»
# ┤ r1(1.571) ├────────────┼─────────────┼──────────────┼───────┤ r1(0.7854) ├»
# ╰─────┬─────╯╭───╮       │             │              │       ╰─────┬──────╯»
# ──────●──────┤ h ├───────┼─────────────┼──────────────┼─────────────┼───────»
#              ╰───╯       │             │              │             │       »
# ─────────────────────────●─────────────●──────────────●─────────────●───────»
#                                                                             »
#
# ################################################################################
#
#                                                                        »
# ─────────────────────────────────────────╳──╳──────────────────────────»
#                                          │  │                          »
# ─────────────────────────────────────────┼──┼───╳───╳──────────────────»
#                                          │  │   │   │                  »
# ─────────────────────────────────────────┼──┼───┼───┼───────╳────────╳─»
# ╭────────────╮                           │  │   │   │       │        │ »
# ┤ rz(0.7854) ├───────────────────────────┼──┼───┼───┼───────╳────────╳─»
# ├───────────┬╯╭───────────╮              │  │   │   │ ╭────────────╮   »
# ┤ r1(1.571) ├─┤ rz(1.571) ├──────────────┼──┼───╳───╳─┤ r1(-1.571) ├───»
# ╰─────┬─────╯ ╰───┬───┬───╯╭───────────╮ │  │ ╭───╮   ╰─────┬──────╯   »
# ──────●───────────┤ h ├────┤ rz(3.142) ├─╳──╳─┤ h ├─────────●──────────»
#                   ╰───╯    ╰───────────╯      ╰───╯                    »
#
# ################################################################################
#
#                                              ╭──────────────╮     »
# ─────────────────────────────────────────────┤ r1(-0.09817) ├─────»
#                               ╭─────────────╮╰──────┬───────╯     »
# ──────────────────────────────┤ r1(-0.1963) ├───────┼─────────────»
#                ╭─────────────╮╰──────┬──────╯       │             »
# ───────────────┤ r1(-0.3927) ├───────┼──────────────┼─────────────»
# ╭─────────────╮╰──────┬──────╯       │              │             »
# ┤ r1(-0.7854) ├───────┼──────────────┼──────────────┼─────────────»
# ╰──────┬──────╯       │              │              │        ╭───╮»
# ───────┼──────────────┼──────────────┼──────────────┼────────┤ h ├»
#        │              │              │              │        ╰───╯»
# ───────●──────────────●──────────────●──────────────●─────────────»
#                                                                   »
#
# ################################################################################
#
#                                             ╭─────────────╮                   »
# ────────────────────────────────────────────┤ r1(-0.1963) ├───────────────────»
#                              ╭─────────────╮╰──────┬──────╯                   »
# ─────────────────────────────┤ r1(-0.3927) ├───────┼──────────────────────────»
#               ╭─────────────╮╰──────┬──────╯       │            ╭────────────╮»
# ──────────────┤ r1(-0.7854) ├───────┼──────────────┼────────────┤ r1(-1.571) ├»
# ╭────────────╮╰──────┬──────╯       │              │       ╭───╮╰─────┬──────╯»
# ┤ r1(-1.571) ├───────┼──────────────┼──────────────┼───────┤ h ├──────●───────»
# ╰─────┬──────╯       │              │              │       ╰───╯              »
# ──────●──────────────●──────────────●──────────────●──────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#                ╭─────────────╮                   ╭─────────────╮     »
# ───────────────┤ r1(-0.3927) ├───────────────────┤ r1(-0.7854) ├─────»
# ╭─────────────╮╰──────┬──────╯     ╭────────────╮╰──────┬──────╯╭───╮»
# ┤ r1(-0.7854) ├───────┼────────────┤ r1(-1.571) ├───────┼───────┤ h ├»
# ╰──────┬──────╯       │       ╭───╮╰─────┬──────╯       │       ╰───╯»
# ───────┼──────────────┼───────┤ h ├──────●──────────────●────────────»
#        │              │       ╰───╯                                  »
# ───────●──────────────●──────────────────────────────────────────────»
#                                                                      »
# ─────────────────────────────────────────────────────────────────────»
#                                                                      »
# ─────────────────────────────────────────────────────────────────────»
#                                                                      »
#
# ################################################################################
#
# ╭────────────╮╭───╮
# ┤ r1(-1.571) ├┤ h ├
# ╰─────┬──────╯╰───╯
# ──────●────────────
#
# ───────────────────
#
# ───────────────────
#
# ───────────────────
#
# ───────────────────

# %% [markdown]
# ### Quantum Phase Estimation

# %%
from phase_estimation import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options,
                api=api)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Jan 25, 2026 20:25:09 UTC
# ... configure execution for target backend_id = density-matrix-cpu
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 8, 0.3
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 8, 0.3, 3.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.083, 0.083 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.883, 0.844
#
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 11, 0.4
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 11, 0.4, 6.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.002, 0.002 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.8, 0.771
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 15, 0.435
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 15, 0.435, 10.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.014, 0.014 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.799, 0.786
#
# ************
# Executing [1] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 20, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 20, 0.5, 15.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.026, 0.026 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.746, 0.738
#
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 27, 0.525
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 27, 0.525, 21.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 0.115, 0.115 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.698, 0.693
#
# ************
# Executing [1] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 34, 0.571
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 34, 0.571, 28.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.434, 0.433 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.656, 0.653
#
# ... execution complete at Jan 25, 2026 20:25:09 UTC in 0.679 secs
#
# Sample Circuit:
#      ╭───╮                                                                    »
# q0 : ┤ h ├──────●─────────────────────────────────────────────────────────────»
#      ├───┤      │                                                             »
# q1 : ┤ h ├──────┼─────────────●───────────────────────────────────────────────»
#      ├───┤      │             │                                               »
# q2 : ┤ h ├──────┼─────────────┼─────────────●─────────────────────────────────»
#      ├───┤      │             │             │                                 »
# q3 : ┤ h ├──────┼─────────────┼─────────────┼─────────────●───────────────────»
#      ├───┤      │             │             │             │                   »
# q4 : ┤ h ├──────┼─────────────┼─────────────┼─────────────┼────────────●──────»
#      ├───┤╭─────┴──────╮╭─────┴──────╮╭─────┴──────╮╭─────┴─────╮╭─────┴─────╮»
# q5 : ┤ x ├┤ r1(0.1963) ├┤ r1(0.3927) ├┤ r1(0.7854) ├┤ r1(1.571) ├┤ r1(3.142) ├»
#      ╰───╯╰────────────╯╰────────────╯╰────────────╯╰───────────╯╰───────────╯»
#
# ################################################################################
#
#                                                           ╭─────────────╮     »
# ─╳──╳─────────────────────────────────────────────────────┤ r1(-0.1963) ├─────»
#  │  │                                      ╭─────────────╮╰──────┬──────╯     »
# ─┼──┼───╳───╳──────────────────────────────┤ r1(-0.3927) ├───────┼────────────»
#  │  │   │   │               ╭─────────────╮╰──────┬──────╯       │            »
# ─┼──┼───┼───┼───────────────┤ r1(-0.7854) ├───────┼──────────────┼────────────»
#  │  │   │   │ ╭────────────╮╰──────┬──────╯       │              │       ╭───╮»
# ─┼──┼───╳───╳─┤ r1(-1.571) ├───────┼──────────────┼──────────────┼───────┤ h ├»
#  │  │ ╭───╮   ╰─────┬──────╯       │              │              │       ╰───╯»
# ─╳──╳─┤ h ├─────────●──────────────●──────────────●──────────────●────────────»
#       ╰───╯                                                                   »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#                              ╭─────────────╮                   ╭─────────────╮»
# ─────────────────────────────┤ r1(-0.3927) ├───────────────────┤ r1(-0.7854) ├»
#               ╭─────────────╮╰──────┬──────╯     ╭────────────╮╰──────┬──────╯»
# ──────────────┤ r1(-0.7854) ├───────┼────────────┤ r1(-1.571) ├───────┼───────»
# ╭────────────╮╰──────┬──────╯       │       ╭───╮╰─────┬──────╯       │       »
# ┤ r1(-1.571) ├───────┼──────────────┼───────┤ h ├──────●──────────────●───────»
# ╰─────┬──────╯       │              │       ╰───╯                             »
# ──────●──────────────●──────────────●─────────────────────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
# ──────────────────────────────────────────────────────────────────────────────»
#                                                                               »
#
# ################################################################################
#
#      ╭────────────╮╭───╮
# ─────┤ r1(-1.571) ├┤ h ├
# ╭───╮╰─────┬──────╯╰───╯
# ┤ h ├──────●────────────
# ╰───╯
# ────────────────────────
#
# ────────────────────────
#
# ────────────────────────
#
# ────────────────────────

# %%
import cudaq
print(cudaq.__version__)
# Out:
# CUDA-Q Version amd64-cu12-0.13.0 (https://github.com/NVIDIA/cuda-quantum b66c5bb7fd8c08e5014e2f03e97e7b0e92691650)
