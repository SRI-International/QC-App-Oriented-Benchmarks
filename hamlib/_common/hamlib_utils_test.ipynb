# %%
import hamlib_utils

hamlib_utils.verbose = True

####################

hamlib_utils.load_from_file("FH_D-1")

hamlib_utils.find_dataset_for_params(12, { "graph-1D-grid": "pbc", "enc": "bk", "U":4 })

####################

hamlib_utils.load_from_file("tfim")

# this should return an array of 9 datasets
hamlib_utils.find_dataset_for_params(12, { "graph-1D-grid": "pbc" })

hamlib_utils.find_dataset_for_params(12, { "graph-1D-grid": "pbc", "h": 0.5 })

####################

hamlib_utils.load_from_file("H2")

# this is an example of a search with a parameter with no value
hamlib_utils.find_dataset_for_params(12, { "ham_JW": "" } )

####################

hamlib_utils.load_from_file("chemistry/vibrational/all-vib-o3")

# this is another example of a search with a parameter with no value
# Unfortunately it finds two datasets; need to find way to force it to be unique
# this is a limitation for now
hamlib_utils.find_dataset_for_params(12, { "enc_unary": "" } )

# remove active HamLib file
hamlib_utils.active_hamiltonian_datasets = None

# this should give error
hamlib_utils.load_from_file("abc")

# this should give error
hamlib_utils.find_dataset_for_params(12, None)

print("")
# Out:
# ... hamlib_utils.load_from_file(FH_D-1)
#   ... fullname = https://portal.nersc.gov/cfs/m888/dcamps/hamlib/condensedmatter/fermihubbard/FH_D-1.zip
#   ... download_and_extract(FH_D-1,https://portal.nersc.gov/cfs/m888/dcamps/hamlib/condensedmatter/fermihubbard/FH_D-1.zip)
#   ... extracted_path = downloaded_hamlib_files
#   ... hdf5_file_path = downloaded_hamlib_files\FH_D-1.hdf5
# ... loaded 1872 datasets.
# ... find_dataset_for_params(12, {'graph-1D-grid': 'pbc', 'enc': 'bk', 'U': 4})
#   ... matching dataset_name = fh-graph-1D-grid-pbc-qubitnodes_Lx-6_U-4_enc-bk
#   ... found 1 datasets.
#
# ... hamlib_utils.load_from_file(tfim)
#   ... fullname = https://portal.nersc.gov/cfs/m888/dcamps/hamlib/condensedmatter/tfim/tfim.zip
#   ... download_and_extract(tfim,https://portal.nersc.gov/cfs/m888/dcamps/hamlib/condensedmatter/tfim/tfim.zip)
#   ... extracted_path = downloaded_hamlib_files
#   ... hdf5_file_path = downloaded_hamlib_files\tfim.hdf5
# ... loaded 7326 datasets.
# ... find_dataset_for_params(12, {'graph-1D-grid': 'pbc'})
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-0
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-0.1
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-0.5
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-1
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-2
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-3
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-4
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-5
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-6
#   ... found 9 datasets.
# ... find_dataset_for_params(12, {'graph-1D-grid': 'pbc', 'h': 0.5})
#   ... matching dataset_name = graph-1D-grid-pbc-qubitnodes_Lx-12_h-0.5
#   ... found 1 datasets.
#
# ... hamlib_utils.load_from_file(H2)
#   ... fullname = https://portal.nersc.gov/cfs/m888/dcamps/hamlib/chemistry/electronic/standard/H2.zip
#   ... download_and_extract(H2,https://portal.nersc.gov/cfs/m888/dcamps/hamlib/chemistry/electronic/standard/H2.zip)
#   ... extracted_path = downloaded_hamlib_files
#   ... hdf5_file_path = downloaded_hamlib_files\H2.hdf5
# ... loaded 20 datasets.
# ... find_dataset_for_params(12, {'ham_JW': ''})
#   ... matching dataset_name = ham_JW-12
#   ... found 1 datasets.
#
# ... hamlib_utils.load_from_file(chemistry/vibrational/all-vib-o3)
#   ... fullname = https://portal.nersc.gov/cfs/m888/dcamps/hamlib/chemistry/vibrational/all-vib-o3.zip
#   ... download_and_extract(chemistry/vibrational/all-vib-o3,https://portal.nersc.gov/cfs/m888/dcamps/hamlib/chemistry/vibrational/all-vib-o3.zip)
#   ... extracted_path = downloaded_hamlib_files
#   ... hdf5_file_path = downloaded_hamlib_files\all-vib-o3.hdf5
# ... loaded 40 datasets.
# ... find_dataset_for_params(12, {'enc_unary': ''})
#   ... matching dataset_name = enc_unary_dvalues_4-4-4
#   ... matching dataset_name = mu_z_prime_enc_unary_dvalues_4-4-4
#   ... found 2 datasets.
#
# ... hamlib_utils.load_from_file(abc)
#   ... fullname = https://portal.nersc.gov/cfs/m888/dcamps/hamlib/abc.zip
#   ... download_and_extract(abc,https://portal.nersc.gov/cfs/m888/dcamps/hamlib/abc.zip)
# ERROR: can not download the requested HamLib file from: https://portal.nersc.gov/cfs/m888/dcamps/hamlib/abc.zip
# ERROR: find_dataset_for_params(), no HamLib file is active.
