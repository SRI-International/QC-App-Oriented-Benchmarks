# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Quantum Reinforcement Learning
#
# - The notebook contains specific examples for the Quantum Reinforcement Learning benchmark program.
# - Configure and run the cell below with the desired execution settings.
# - Then configure and run the remaining cell(s), each one a variation of this benchmark.

# %%
import os, sys, copy
import time, random
import numpy as np
from qiskit_ibm_runtime import QiskitRuntimeService
QiskitRuntimeService.save_account(instance =  "crn:v1:bluemix:public:quantum-computing:us-east:a/1d194ddd99a94496b8f253cb72212526:6f07487f-bcc0-435e-a042-3def311b8213::", token = 'dzwFUPe5wplxzdI2k4xD2rKFl9xu7-Xx3DbKnDfyAPif', overwrite= True)  # only need to do this first time
min_qubits=4
max_qubits=12
skip_qubits=2
max_circuits=3
num_shots=1000

backend_id="qasm_simulator"
#backend_id="statevector_simulator"

hub=""; group=""; project=""
provider_backend = None
exec_options = {}

# *** If you use `ibm_cloud` channel, set hub, group, and project name here
hub=""; group=""; project="crn:v1:bluemix:public:quantum-computing:us-east:a/1d194ddd99a94496b8f253cb72212526:6f07487f-bcc0-435e-a042-3def311b8213::"

# *** This example shows how to specify an IBMQ backend using a known "backend_id"
#    See the App-Oriented Benchmarks setup page documentation for more info ob backends and options. 
exec_options = {
    "use_ibm_quantum_platform": False,
    "use_sessions": False,
    "sampler_options" : {
            "dynamical_decoupling": {
                "enable": True}}
}
backend_id="ibm_brisbane"

# %%
import sys
import qrl_benchmark


qrl_benchmark.run(api="qiskit", min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=3, num_layers=5, num_shots=num_shots, init_state = 7, backend_id=backend_id, hub=hub, group=group, project=project, exec_options=exec_options, data_reupload=True)
# Out:
# Quantum-Reinforcement-Learning (1) Benchmark Program
# ... execution starting at Jul 31, 2025 22:18:47 UTC
# ... using Qiskit Runtime channel='ibm_cloud' instance='crn:v1:bluemix:public:quantum-computing:us-east:a/1d194ddd99a94496b8f253cb72212526:6f07487f-bcc0-435e-a042-3def311b8213::'
# ... using backend=<IBMBackend('ibm_brisbane')> primitive_name='sampler'
# ...

# %%
import sys
import qrl_benchmark


qrl_benchmark.run(api="qiskit", min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=3, num_layers=5, num_shots=num_shots, init_state = 255, backend_id=backend_id, hub=hub, group=group, project=project, exec_options=exec_options, method=3, n_measurements=8, num_qubits=8, data_reupload=True)
# Out:
# Quantum-Reinforcement-Learning (3) Benchmark Program
# ... execution starting at Aug 04, 2025 04:01:24 UTC
# ... using Qiskit Runtime channel='ibm_cloud' instance='crn:v1:bluemix:public:quantum-computing:us-east:a/1d194ddd99a94496b8f253cb72212526:6f07487f-bcc0-435e-a042-3def311b8213::'
# ... using backend=<IBMBackend('ibm_brisbane')> primitive_name='sampler'
# ...
