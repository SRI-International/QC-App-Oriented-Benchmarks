# %% [markdown]
# ### QED-C Prototype Benchmarks - Q-CTRL Fire Opal Version
# The notebook contains a suite of prototype application benchmarks for Q-CTRL's Fire Opal API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one prototype benchmark program.

# %%
min_qubits=2
max_qubits=7
max_circuits=1
num_shots=1000

import _common.executors.fire_opal_executor as fire_opal_executor
from _common.executors.fire_opal_executor import FireOpalBackend

hub = "YOUR_HUB_HERE"
group = "YOUR_GROUP_HERE"
project = "YOUR_PROJECT_HERE"
token = "YOUR_TOKEN_HERE"

ibm_backend_id = "ibmq_jakarta"
backend_id = f"fire_opal_{ibm_backend_id}"
provider_backend = FireOpalBackend(ibm_backend_id=ibm_backend_id, hub=hub, group=group, project=project, token=token)
exec_options = {"executor": fire_opal_executor.run}

fire_opal_executor.verbose = True

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa/qiskit")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Deutsch-Jozsa Benchmark Program - Qiskit
# 1
# ... execution starting at Aug 24, 2023 21:14:28 UTC
# ************
# Executing [1] circuits with num_qubits = 3
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Warning: The readout error rate on ibmq_jakarta is much higher than the median right now. This will negatively impact Fire Opal’s performance. To see better results, try running on a different device. Visit https://quantum-computing.ibm.com/services/resources?tab=systems&system=ibmq_jakarta for information on device error rates.
#   warn(warning, RuntimeWarning)
# ... result = {'00': 0.9968359611065439, '01': 0.001395974491294233, '10': 0.0017680644021619727}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.004, 29.568, 29.548 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.997, 0.996
#
# ************
# Executing [1] circuits with num_qubits = 4
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000': 0.9870868264204261, '001': 0.005575067213857259, '010': 0.0037292349215685334, '100': 0.0036088714441481883}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.002, 30.423, 30.404 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.987, 0.985
#
# ************
# Executing [1] circuits with num_qubits = 5
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'0000': 0.9725198049978034, '0001': 0.00923158676852646, '0010': 0.0071613355287604335, '0011': 0.0007840373046544623, '0100': 0.004859510194638479, '1000': 0.0036061769129820662, '1001': 0.0008675749002908582, '1100': 0.0009699733923439278}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.003, 30.303, 30.285 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.973, 0.971
#
# ************
# Executing [1] circuits with num_qubits = 6
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'00000': 0.9815476680208106, '00001': 0.00031197058244244856, '00010': 0.00466649599484832, '00100': 0.007318439121968952, '01000': 0.002710413609467223, '10000': 0.0034450126704624003}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 5, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 30.579, 30.56 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.982, 0.981
#
# ************
# Executing [1] circuits with num_qubits = 7
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000000': 0.9731898890481201, '000001': 0.006763221919481387, '000100': 0.004023817284929433, '010000': 0.01602307174746897}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 6, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 6, 0.0, 0.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.001, 44.692, 44.674 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.973, 0.973
#
# ... execution complete at Aug 24, 2023 21:17:14 UTC in 165.674 secs
#
# Sample Circuit:
#        ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q17_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#        ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q17_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q17_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#        ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q17_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q17_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#        ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q17_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#        └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c3: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                             0  1  2  3  4
#
# Constant Oracle 'Uf' =
#
# q_0:
#
# q_1:
#
# q_2:
#
# q_3:
#
# q_4:
#
# q_5:
#
#
# Balanced Oracle 'Uf' =
#  ... too large or not used!

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani Benchmark Program - Qiskit
# ... execution starting at Aug 24, 2023 21:29:53 UTC
# ************
# Executing [1] circuits with num_qubits = 3
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Warning: The readout error rate on ibmq_jakarta is much higher than the median right now. This will negatively impact Fire Opal’s performance. To see better results, try running on a different device. Visit https://quantum-computing.ibm.com/services/resources?tab=systems&system=ibmq_jakarta for information on device error rates.
#   warn(warning, RuntimeWarning)
# ... result = {'00': 0.00867839171402104, '01': 2.8192166929164736e-06, '10': 0.9662989463661031, '11': 0.02501984270318286}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 6, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 6, 0.091, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 56.832, 56.819 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.966, 0.955
#
# ************
# Executing [1] circuits with num_qubits = 4
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000': 0.014160878407960995, '001': 0.0014974839933950025, '010': 0.9723768845121487, '011': 0.0006924747092007597, '110': 0.011272278377294451}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 6, 0.091
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0.067, 1.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.003, 52.683, 52.662 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.972, 0.968
#
# ************
# Executing [1] circuits with num_qubits = 5
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'0000': 0.009895198717403611, '0001': 0.006830650102718537, '0101': 0.9596536338257706, '0111': 0.016300980085675227, '1101': 0.007319537268432057}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 7, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 7, 0.1, 2.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.002, 35.097, 35.08 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.96, 0.957
#
# ************
# Executing [1] circuits with num_qubits = 6
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'00000': 0.007722631777816026, '00001': 0.008553324071958593, '00010': 0.0009882767281720723, '00011': 0.002529902711186574, '10000': 9.311577925844635e-05, '10010': 0.0018008919257884045, '10011': 0.028629197173776547, '10110': 0.10077643821105302, '10111': 0.8005832526453397, '11110': 0.0003935582231880106, '11111': 0.04792941075246262}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 9, 0.222
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 9, 0.154, 4.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.002, 55.056, 55.038 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.801, 0.794
#
# ************
# Executing [1] circuits with num_qubits = 7
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000000': 0.014412030770602947, '000100': 2.4304888069764377e-05, '000110': 0.001542120057932929, '001010': 0.9470857154357828, '001011': 0.003990188226481871, '001110': 0.010051263194902382, '010010': 0.00030422869828343664, '011000': 0.0026963326773396567, '011010': 0.006874497762602758, '100000': 3.317436398235095e-05, '100010': 0.0014303852092633035, '100110': 0.0001536970633577745, '101010': 0.01088313344807029, '101011': 0.00020003310815068032, '101110': 9.222919504657024e-05, '111010': 0.00022666590013035418}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 7, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 7, 0.071, 2.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.002, 30.552, 30.532 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.947, 0.946
#
# ... execution complete at Aug 24, 2023 21:33:43 UTC in 230.3 secs
#
# Sample Circuit:
#        ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q21_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#        ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q21_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q21_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#        ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q21_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q21_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#        ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q21_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#        └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c3: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                             0  1  2  3  4
#
# Quantum Oracle 'Uf' =
#
# q22_0: ──■─────────────────
#          │
# q22_1: ──┼────■────────────
#          │    │
# q22_2: ──┼────┼────■───────
#          │    │    │
# q22_3: ──┼────┼────┼───────
#          │    │    │
# q22_4: ──┼────┼────┼────■──
#        ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐
# q22_5: ┤ X ├┤ X ├┤ X ├┤ X ├
#        └───┘└───┘└───┘└───┘

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
# This benchmark is commented out because mid-circuit measurements aren't supported in Fire Opal as of September 2023.

# import sys
# sys.path.insert(1, "bernstein-vazirani/qiskit")
# import bv_benchmark
# bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
#                 method=2,
#                 backend_id=backend_id, provider_backend=provider_backend,
#                 hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift/qiskit")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Aug 24, 2023 21:48:28 UTC
# ************
# Executing [1] circuits with num_qubits = 2
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Warning: The readout error rate on ibmq_jakarta is much higher than the median right now. This will negatively impact Fire Opal’s performance. To see better results, try running on a different device. Visit https://quantum-computing.ibm.com/services/resources?tab=systems&system=ibmq_jakarta for information on device error rates.
#   warn(warning, RuntimeWarning)
# ... result = {'00': 0.011789225817985078, '01': 0.009513994597740213, '10': 0.9717161789492987, '11': 0.006980600634976022}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 15, 0.1, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.001, 88.574, 88.561 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.972, 0.962
#
# ************
# Executing [1] circuits with num_qubits = 4
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'0010': 0.0280430993737274, '0011': 0.0036174016102113542, '0100': 0.0008000209886943352, '0110': 6.619558395361985e-06, '1000': 0.012177652687351185, '1001': 0.018940647688237586, '1010': 0.7746745364892441, '1011': 0.1518555726774218, '1101': 0.0005747395649401, '1110': 0.0071514581576323675, '1111': 0.0021582512041444374}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 15, 0.1, 4.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.003, 86.471, 86.453 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.775, 0.76
#
# ************
# Executing [1] circuits with num_qubits = 6
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000000': 0.00985336044097438, '000001': 0.0024346819596470313, '000010': 0.022312422801163762, '000011': 0.001582913489379124, '000100': 0.0008297654421909747, '001010': 0.0005516100099729975, '001100': 0.0009749799487951349, '010000': 0.003403225657004922, '010001': 0.00036184805298619693, '010010': 0.0203874195054823, '010011': 0.007055476381288699, '010100': 0.0007945565270150209, '010111': 0.00184978636098566, '011010': 0.0007992304067882558, '011100': 0.0009197358573356312, '011110': 0.0003858915449223815, '100000': 0.008859295085915207, '100001': 0.009141920657629345, '100010': 0.03499859224018182, '100011': 0.01301454881685928, '100110': 0.004809492249293236, '100111': 0.0006477393572680707, '101010': 0.0027394816057418397, '101110': 0.0030721253224865793, '110000': 0.01517634773871801, '110001': 0.015083817918708262, '110010': 0.6953981830112592, '110011': 0.021666376833129462, '110110': 0.041763561710019055, '110111': 0.0064910107407079335, '111000': 0.002364799578411616, '111001': 0.0010637470334441772, '111010': 0.03822728510515686, '111100': 0.00042209716846223035, '111110': 0.010562673440675673}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.2
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 17, 0.094, 6.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.002, 30.395, 30.373 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.695, 0.691
#
# ... execution complete at Aug 24, 2023 21:51:54 UTC in 205.512 secs
#
# Sample Circuit:
#        ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─┐
# q16_0: ┤ H ├─░─┤0    ├─░─┤ H ├─░─┤0    ├─░─┤ H ├─░─┤M├───────────────
#        ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░ └╥┘┌─┐
# q16_1: ┤ H ├─░─┤1    ├─░─┤ H ├─░─┤1    ├─░─┤ H ├─░──╫─┤M├────────────
#        ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║ └╥┘┌─┐
# q16_2: ┤ H ├─░─┤2    ├─░─┤ H ├─░─┤2    ├─░─┤ H ├─░──╫──╫─┤M├─────────
#        ├───┤ ░ │  Uf │ ░ ├───┤ ░ │  Ug │ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# q16_3: ┤ H ├─░─┤3    ├─░─┤ H ├─░─┤3    ├─░─┤ H ├─░──╫──╫──╫─┤M├──────
#        ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║ └╥┘┌─┐
# q16_4: ┤ H ├─░─┤4    ├─░─┤ H ├─░─┤4    ├─░─┤ H ├─░──╫──╫──╫──╫─┤M├───
#        ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# q16_5: ┤ H ├─░─┤5    ├─░─┤ H ├─░─┤5    ├─░─┤ H ├─░──╫──╫──╫──╫──╫─┤M├
#        └───┘ ░ └─────┘ ░ └───┘ ░ └─────┘ ░ └───┘ ░  ║  ║  ║  ║  ║ └╥┘
#  c2: 6/═════════════════════════════════════════════╩══╩══╩══╩══╩══╩═
#                                                     0  1  2  3  4  5
#
# Quantum Oracle 'Uf' =
#
# q17_0: ──────■──────
#        ┌───┐ │ ┌───┐
# q17_1: ┤ X ├─■─┤ X ├
#        └───┘   └───┘
# q17_2: ──■──────────
#          │
# q17_3: ──■──────────
#        ┌───┐   ┌───┐
# q17_4: ┤ X ├─■─┤ X ├
#        ├───┤ │ ├───┤
# q17_5: ┤ X ├─■─┤ X ├
#        └───┘   └───┘
#
# Quantum Oracle 'Ug' =
#
# q18_0: ─■─
#         │
# q18_1: ─■─
#
# q18_2: ─■─
#         │
# q18_3: ─■─
#
# q18_4: ─■─
#         │
# q18_5: ─■─

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
#
# q27_3: ┤ X ├─░─┤3     ├─░─┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├───
#        └───┘ ░ │      │ ░ ├─────────┴┐ ░ │          │ ░  ║  ║  ║ └╥┘┌─┐
# q27_4: ──────░─┤4     ├─░─┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├
#              ░ └──────┘ ░ └──────────┘ ░ └──────────┘ ░  ║  ║  ║  ║ └╥┘
#  c3: 5/══════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                          0  1  2  3  4
#
# QFT Circuit =
#              ░                  ░                             ░            »
# q28_0: ──────░──────────────────░─────────────────────────────░────────────»
#              ░                  ░                             ░            »
# q28_1: ──────░──────────────────░─────────────────────────────░──────■─────»
#              ░                  ░                       ┌───┐ ░      │     »
# q28_2: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#              ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q28_3: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#        ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q28_4: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#        └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                   ░                                   »
# «q28_0: ────────────────────────────░──────■───────────■──────────■─────»
# «                             ┌───┐ ░      │           │          │     »
# «q28_1: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «            │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q28_2: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «       ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q28_3: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «       └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q28_4: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                   ░ └──────────┘                      »
# «                  ┌───┐ ░
# «q28_0: ─────■─────┤ H ├─░─
# «       ┌────┴────┐└───┘ ░
# «q28_1: ┤ Rz(π/2) ├──────░─
# «       └─────────┘      ░
# «q28_2: ─────────────────░─
# «                        ░
# «q28_3: ─────────────────░─
# «                        ░
# «q28_4: ─────────────────░─
# «                        ░
#
# Inverse QFT Circuit =
#        ┌───┐                                                  ░      »
# q29_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#        └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q29_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#             └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q29_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                         └──────────┘┌────┴─────┐      │       ░      »
# q29_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                     └──────────┘┌─────┴─────┐ ░      »
# q29_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                 └───────────┘ ░      »
# «                                            ░                               ░ »
# «q29_0: ─────────────────────────────────────░───────────────────────────────░─»
# «                                            ░                               ░ »
# «q29_1: ─────■───────────■───────────■───────░───────────────────────────────░─»
# «       ┌────┴─────┐     │           │       ░ ┌───┐                         ░ »
# «q29_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■───────░─»
# «       └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │       ░ »
# «q29_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼───────░─»
# «                   └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐ ░ »
# «q29_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├─░─»
# «                               └──────────┘ ░                  └──────────┘ ░ »
# «                         ░       ░
# «q29_0: ──────────────────░───────░─
# «                         ░       ░
# «q29_1: ──────────────────░───────░─
# «                         ░       ░
# «q29_2: ──────────────────░───────░─
# «       ┌───┐             ░       ░
# «q29_3: ┤ H ├─────■───────░───────░─
# «       └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q29_4: ─────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «            └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at Aug 24, 2023 22:08:00 UTC
# ************
# Executing [1] circuits with num_qubits = 2
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Warning: The readout error rate on ibmq_jakarta is much higher than the median right now. This will negatively impact Fire Opal’s performance. To see better results, try running on a different device. Visit https://quantum-computing.ibm.com/services/resources?tab=systems&system=ibmq_jakarta for information on device error rates.
#   warn(warning, RuntimeWarning)
# ... result = {'00': 0.03262253788871336, '01': 0.0005774787738124679, '10': 0.9667999833374742}
# ... number of gates, depth = 9, 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 6, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.286, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.001, 29.728, 29.716 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.967, 0.956
#
# ************
# Executing [1] circuits with num_qubits = 3
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000': 0.003670884302976116, '010': 0.06639314461095494, '011': 0.01538794855320942, '100': 0.014242050489845766, '101': 0.005312872087748366, '110': 0.8395971878472902, '111': 0.05539591210797538}
# ... number of gates, depth = 15, 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 9, 0.25
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 16, 0.333, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 30.538, 30.526 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.84, 0.817
#
# ************
# Executing [1] circuits with num_qubits = 4
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'0000': 0.05227639599635578, '0001': 0.7506912188431908, '0010': 0.004335653319917811, '0011': 0.04037677400349008, '0100': 0.00018012641892254172, '0101': 0.03188218312078373, '0111': 0.015546827939755254, '1001': 0.04461826147791729, '1010': 0.0019222582858150498, '1100': 0.002899524035907695, '1101': 0.030516390161898246, '1110': 0.0036237560628369463, '1111': 0.021130630333208805}
# ... number of gates, depth = 22, 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 13, 0.333
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.353, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.003, 31.129, 31.111 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.751, 0.734
#
# ************
# Executing [1] circuits with num_qubits = 5
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'
secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.201, 0.195
#
# ... execution complete at Aug 24, 2023 22:11:27 UTC in 207.001 secs
#
# Sample Circuit:
#        ┌───┐ ┌─────────┐  ┌──────────┐┌─┐
# q24_0: ┤ H ├─┤ Rz(11π) ├──┤0         ├┤M├────────────
#        ├───┤┌┴─────────┴┐ │          │└╥┘┌─┐
# q24_1: ┤ H ├┤ Rz(11π/2) ├─┤1         ├─╫─┤M├─────────
#        ├───┤├───────────┤ │          │ ║ └╥┘┌─┐
# q24_2: ┤ H ├┤ Rz(11π/4) ├─┤2 inv_qft ├─╫──╫─┤M├──────
#        ├───┤├───────────┤ │          │ ║  ║ └╥┘┌─┐
# q24_3: ┤ H ├┤ Rz(11π/8) ├─┤3         ├─╫──╫──╫─┤M├───
#        ├───┤├───────────┴┐│          │ ║  ║  ║ └╥┘┌─┐
# q24_4: ┤ H ├┤ Rz(11π/16) ├┤4         ├─╫──╫──╫──╫─┤M├
#        └───┘└────────────┘└──────────┘ ║  ║  ║  ║ └╥┘
#  c3: 5/════════════════════════════════╩══╩══╩══╩══╩═
#                                        0  1  2  3  4
#
# Inverse QFT Circuit =
#        ┌───┐                                                  ░      »
# q25_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#        └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q25_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#             └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q25_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                         └──────────┘┌────┴─────┐      │       ░      »
# q25_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                     └──────────┘┌─────┴─────┐ ░      »
# q25_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                 └───────────┘ ░      »
# «                                            ░                               ░ »
# «q25_0: ─────────────────────────────────────░───────────────────────────────░─»
# «                                            ░                               ░ »
# «q25_1: ─────■───────────■───────────■───────░───────────────────────────────░─»
# «       ┌────┴─────┐     │           │       ░ ┌───┐                         ░ »
# «q25_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■───────░─»
# «       └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │       ░ »
# «q25_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼───────░─»
# «                   └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐ ░ »
# «q25_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├─░─»
# «                               └──────────┘ ░                  └──────────┘ ░ »
# «                         ░       ░
# «q25_0: ──────────────────░───────░─
# «                         ░       ░
# «q25_1: ──────────────────░───────░─
# «                         ░       ░
# «q25_2: ──────────────────░───────░─
# «       ┌───┐             ░       ░
# «q25_3: ┤ H ├─────■───────░───────░─
# «       └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q25_4: ─────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «            └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers/qiskit")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
#
─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░  ║  ║  ║  ║ └╥┘
# « c3: 5/═══════════════════════════════════════════════════════╩══╩══╩══╩══╩═
# «                                                              0  1  2  3  4
#
# Oracle =
#                        ░
# q41_0: ───────■────────░──────
#               │        ░
# q41_1: ───────■────────░──────
#               │        ░
# q41_2: ───────■────────░──────
#        ┌───┐  │        ░ ┌───┐
# q41_3: ┤ X ├──■────────░─┤ X ├
#        ├───┤┌─┴─┐┌───┐ ░ └───┘
# q41_4: ┤ H ├┤ X ├┤ H ├─░──────
#        └───┘└───┘└───┘ ░
#
# Diffuser =
#        ┌───┐┌───┐                ░ ┌───┐┌───┐
# q42_0: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#        ├───┤├───┤       │        ░ ├───┤├───┤
# q42_1: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#        ├───┤├───┤       │        ░ ├───┤├───┤
# q42_2: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#        ├───┤├───┤       │        ░ ├───┤├───┤
# q42_3: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#        ├───┤├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤├───┤
# q42_4: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├┤ H ├
#        └───┘└───┘└───┘└───┘└───┘ ░ └───┘└───┘

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Aug 24, 2023 22:41:38 UTC
# ************
# Executing [1] circuits with num_qubits = 3
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Warning: The readout error rate on ibmq_jakarta is much higher than the median right now. This will negatively impact Fire Opal’s performance. To see better results, try running on a different device. Visit https://quantum-computing.ibm.com/services/resources?tab=systems&system=ibmq_jakarta for information on device error rates.
#   warn(warning, RuntimeWarning)
# ... result = {'00': 0.030449578668299723, '01': 0.002794777608152994, '10': 0.9625068274092108, '11': 0.004248816314336513}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 16, 0.316
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 19, 0.261, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.009, 30.177, 30.145 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.963, 0.95
#
# ************
# Executing [1] circuits with num_qubits = 4
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000': 0.051104307885857785, '001': 0.009897736701278961, '010': 0.015951628922351725, '011': 0.0029840698435431674, '100': 0.8787249721900539, '101': 0.02290680437880831, '110': 0.016541428481704094, '111': 0.001889051596401947}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 27, 0.353
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.286, 10.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.008, 30.488, 30.468 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.879, 0.861
#
# ************
# Executing [1] circuits with num_qubits = 5
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'0000': 0.10232913934595597, '0001': 0.003969258417749671, '0010': 0.00958027055215055, '0011': 0.002470771825909739, '0100': 0.06258698929227359, '0101': 0.0049613770688161, '0110': 0.007304980586805163, '0111': 0.0036676997709046196, '1000': 0.08028560723366139, '1001': 0.0009864556594679753, '1010': 0.024678205793093332, '1011': 0.01490854874062096, '1100': 0.5916230575192557, '1101': 0.01904568198892893, '1110': 0.051919523017621004, '1111': 0.01968243318678523}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 41, 0.377
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 42, 0.321, 18.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.013, 30.742, 30.714 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.592, 0.564
#
# ************
# Executing [1] circuits with num_qubits = 6
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'00000': 0.07084491770554528, '00001': 0.02048878963109623, '00010': 0.4106744714930981, '00011': 0.05562803917322788, '00100': 0.05343123728553058, '00101': 0.007985946228269205, '00110': 0.03362806677394664, '00111': 0.004806759899923049, '01000': 0.01155245040932802, '01001': 0.0021374141254350706, '01010': 0.014315475441858237, '01011': 0.003976358346354792, '01100': 0.009256087801807823, '01101': 0.0034964372243025733, '01110': 0.009761661146287525, '01111': 0.0038794000254489466, '10000': 0.014716268455301093, '10001': 0.004181855500699119, '10010': 0.09777600175441756, '10011': 0.01574420269644061, '10100': 0.010953788022288337, '10101': 0.005261943396266385, '10110': 0.025914956814713005, '10111': 0.00502694254411112, '11000': 0.015143451586601164, '11001': 0.0046139352946910905, '11010': 0.023520629530973725, '11011': 0.010116432871333625, '11100': 0.015019124190781932, '11101': 0.0037446347323456717, '11110': 0.02347597709390795, '11111': 0.00892634280366774}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 58, 0.395
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 64, 0.349, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.014, 38.188, 38.154 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.411, 0.392
#
# ************
# Executing [1] circuits with num_qubits = 7
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Circuit number 0
#  c2: 4/═══════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                               0  1  2  3
#
# Phase Operator 'U' =
#    ┌─────────┐
# q: ┤ P(3π/2) ├
#    └─────────┘
#
# Inverse QFT Circuit =
#        ┌───┐                                     ░                  »
# q24_0: ┤ H ├─────■───────────■───────────■───────░──────────────────»
#        └───┘┌────┴─────┐     │           │       ░ ┌───┐            »
# q24_1: ─────┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■──────»
#             └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐»
# q24_2: ─────────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├»
#                         └──────────┘┌────┴─────┐ ░      └──────────┘»
# q24_3: ─────────────────────────────┤ Rz(-π/8) ├─░──────────────────»
#                                     └──────────┘ ░                  »
# «                    ░                   ░       ░
# «q24_0: ─────────────░───────────────────░───────░─
# «                    ░                   ░       ░
# «q24_1: ─────■───────░───────────────────░───────░─
# «            │       ░ ┌───┐             ░       ░
# «q24_2: ─────┼───────░─┤ H ├─────■───────░───────░─
# «       ┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q24_3: ┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «       └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### HHL Linear Solver

# %%
# This benchmark is commented out because custom unitary operators aren't supported in Fire Opal as of September 2023.

# import sys
# sys.path.insert(1, "hhl/qiskit")
# import hhl_benchmark

# hhl_benchmark.verbose=False

# hhl_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
#                 method=1, use_best_widths=True,
#                 backend_id=backend_id, provider_backend=provider_backend,
#                 hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Aug 24, 2023 22:54:47 UTC
# ************
# Executing [1] circuits with num_qubits = 3
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Warning: The readout error rate on ibmq_jakarta is much higher than the median right now. This will negatively impact Fire Opal’s performance. To see better results, try running on a different device. Visit https://quantum-computing.ibm.com/services/resources?tab=systems&system=ibmq_jakarta for information on device error rates.
#   warn(warning, RuntimeWarning)
# ... result = {'0': 0.18590297824769747, '1': 0.8140970217523025}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 61, 0.385, 30.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.016, 34.505, 34.471 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.814, 0.628
#
# ************
# Executing [1] circuits with num_qubits = 4
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'00': 0.09661537065663035, '01': 0.0027402378083856136, '10': 0.8944326270397593, '11': 0.00621176449522471}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 175, 0.398, 88.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.021, 69.805, 69.73 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.894, 0.859
#
# ************
# Executing [1] circuits with num_qubits = 5
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000': 0.10424202218409506, '001': 0.013468462443976372, '010': 0.3080015744606459, '011': 0.02788779018059219, '100': 0.08503009972380211, '101': 0.018900549109584094, '110': 0.43592388226753276, '111': 0.006545619629771446}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 363, 0.404, 188.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.032, 70.427, 70.247 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.738, 0.651
#
# ************
# Executing [1] circuits with num_qubits = 6
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Circuit number 0 may be nearing or exceeding the T1 limit. Fire Opal improvement may be limited.
#   warn(warning, RuntimeWarning)
# ... result = {'0000': 0.0988947985424267, '0001': 0.10204079051578215, '0010': 0.04198214342938935, '0011': 0.06285605376557436, '0100': 0.048669899542597046, '0101': 0.0507332957366232, '0110': 0.01995270559385729, '0111': 0.06154753234667925, '1000': 0.05022082530027632, '1001': 0.04401362246148155, '1010': 0.024392191726463324, '1011': 0.06055695050661199, '1100': 0.03419074539062988, '1101': 0.08249190771097215, '1110': 0.05455219962255302, '1111': 0.16290433780808244}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.064, 117.193, 116.595 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.261, 0.156
#
# ************
# Executing [1] circuits with num_qubits = 7
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'00000': 0.032417553441605775, '00001': 0.027156847731025693, '00010': 0.01408983963593099, '00011': 0.03095561095520468, '00100': 0.038472487101255795, '00101': 0.030530992611482864, '00110': 0.007297291841064601, '00111': 0.033004126968284864, '01000': 0.029322025003424557, '01001': 0.027014790165426683, '01010': 0.011811770084371946, '01011': 0.050531103163639825, '01100': 0.016733941070238977, '01101': 0.04329913019125673, '01110': 0.01357254324559111, '01111': 0.03054271207593428, '10000': 0.01892462171732428, '10001': 0.035966824906775434, '10010': 0.02379434597906074, '10011': 0.03802073390266457, '10100': 0.03228930758257943, '10101': 0.05247557424929529, '10110': 0.020357514093571893, '10111': 0.039410577103186475, '11000': 0.03888879360959644, '11001': 0.03247727563455338, '11010': 0.02527366090372229, '11011': 0.051836319908306686, '11100': 0.05688767590981172, '11101': 0.04196756190821327, '11110': 0.013327335998612345, '11111': 0.04134911130698631}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.719, 211.415, 210.686 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.103, 0.043
#
# ... execution complete at Aug 24, 2023 23:03:13 UTC in 505.692 secs
#
# Sample Circuit:
#        ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q34_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#        ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q34_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#        ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q34_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#        ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q33_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#        │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q33_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#        └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#  c2: 3/═════════════════════════════════════════════════════════════════»
#                                                                         »
# «       ┌──────────┐ ░ ┌─┐
# «q34_0: ┤0         ├─░─┤M├──────
# «       │          │ ░ └╥┘┌─┐
# «q34_1: ┤1 inv_qft ├─░──╫─┤M├───
# «       │          │ ░  ║ └╥┘┌─┐
# «q34_2: ┤2         ├─░──╫──╫─┤M├
# «       └──────────┘ ░  ║  ║ └╥┘
# «q33_0: ─────────────░──╫──╫──╫─
# «                    ░  ║  ║  ║
# «q33_1: ─────────────░──╫──╫──╫─
# «                    ░  ║  ║  ║
# « c2: 3/════════════════╩══╩══╩═
# «                       0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q68: ──■───
#      ┌─┴──┐
# q_0: ┤0   ├
#      │  Q │
# q_1: ┤1   ├
#      └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.1604) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#        ┌───┐                         ░                   ░       ░
# q36_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#        └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q36_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#             └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q36_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                         └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Monte Carlo Sampling Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at Aug 24, 2023 23:10:58 UTC
# ************
# Executing [1] circuits with num_qubits = 4
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Warning: The readout error rate on ibmq_jakarta is much higher than the median right now. This will negatively impact Fire Opal’s performance. To see better results, try running on a different device. Visit https://quantum-computing.ibm.com/services/resources?tab=systems&system=ibmq_jakarta for information on device error rates.
#   warn(warning, RuntimeWarning)
# ... result = {'00': 0.20634860793937232, '01': 0.28267471750774953, '10': 0.2047296172674971, '11': 0.3062470572853811}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 202, 0.398
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 208, 0.372, 96.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.025, 81.703, 81.605 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.589, 0.177
#
# ************
# Executing [1] circuits with num_qubits = 5
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'000': 0.13014596656088015, '010': 0.2859170635617702, '100': 0.21078790154641366, '110': 0.373149068330936}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 468, 0.401
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 479, 0.377, 224.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.035, 72.817, 72.532 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.656, 0.542
#
# ************
# Executing [1] circuits with num_qubits = 6
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# ... result = {'0000': 0.14104253118468427, '0001': 0.01346071590458417, '0010': 0.015161323673760739, '0011': 0.007006305731258895, '0100': 0.2527052529250596, '0101': 0.03754952449230585, '0110': 0.01574883702972266, '0111': 0.02502902387951082, '1000': 0.12061937451426888, '1001': 0.011535991148156769, '1010': 0.01609947556704938, '1011': 0.009359141708494159, '1100': 0.2596031752498462, '1101': 0.02156273028702252, '1110': 0.04631283699845303, '1111': 0.007203759705822137}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 997, 0.402
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1017, 0.38, 478.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.048, 116.508, 116.07 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.512, 0.443
#
# ************
# Executing [1] circuits with num_qubits = 7
#    ... executing circuit on backend=Fire Opal (ibmq_jakarta)
# /Users/smarakmaity/miniconda3/envs/qedc/lib/python3.10/site-packages/qctrlclient/core/functions.py:84: RuntimeWarning: Circuit number 0 may be nearing or exceeding the T1 limit. Fire Opal improvement may be limited.
#   warn(warning, RuntimeWarning)
# ... result = {'00000': 0.10579576096089088, '00001': 0.017049669865881488, '00010': 0.008601955999301537, '00011': 0.0027902106857160746, '00100': 0.032966846540244905, '00101': 0.00611200923961785, '00110': 0.015219456898457695, '00111': 0.003590959281271296, '01000': 0.18506654935410413, '01001': 0.032224970335893874, '01010': 0.01968927315372556, '01011': 0.028651578199320807, '01100': 0.03884152505104962, '01101': 0.0120513925044252, '01110': 0.02101129834817974, '01111': 0.012029926907626835, '10000': 0.06919237696619837, '10001': 0.013191086816865878, '10010': 0.006931587203814545, '10011': 0.007798739935497368, '10100': 0.03582772763619768, '10101': 0.0003898757300719701, '10110': 0.011322728047619954, '10111': 0.0019766332709821952, '11000': 0.1762351448891123, '11001': 0.029045453906824413, '11010': 0.030081343019061915, '11011': 0.01006134648576568, '11100': 0.03261500151923049, '11101': 0.006602809808822855, '11110': 0.02037890487735031, '11111': 0.006655856560876574}
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2049, 0.402
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2086, 0.382, 982.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.076, 210.796, 209.963 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.361, 0.319
#
# ... execution complete at Aug 24, 2023 23:19:01 UTC in 483.159 secs
#
# Sample Circuit:
#        ┌────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q19_0: ┤0   ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#        │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q19_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├─░─»
#        ├───┬┘│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q20_0: ┤ H ├─┤  c_Q ├┤      ├┤      ├┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#        ├───┤ │      ││      ││      │└──────┘└──────┘└──────┘└──────┘ ░ »
# q20_1: ┤ H ├─┤      ├┤0     ├┤0     ├─────────────────────────────────░─»
#        ├───┤ │      │└──────┘└──────┘                                 ░ »
# q20_2: ┤ H ├─┤0     ├─────────────────────────────────────────────────░─»
#        └───┘ └──────┘                                                 ░ »
#  c1: 3/═════════════════════════════════════════════════════════════════»
#                                                                         »
# «                    ░
# «q19_0: ─────────────░──────────
# «                    ░
# «q19_1: ─────────────░──────────
# «       ┌──────────┐ ░ ┌─┐
# «q20_0: ┤0         ├─░─┤M├──────
# «       │          │ ░ └╥┘┌─┐
# «q20_1: ┤1 inv_qft ├─░──╫─┤M├───
# «       │          │ ░  ║ └╥┘┌─┐
# «q20_2: ┤2         ├─░──╫──╫─┤M├
# «       └──────────┘ ░  ║  ║ └╥┘
# « c1: 3/════════════════╩══╩══╩═
# «                       0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q52: ──■───
#      ┌─┴──┐
# q_0: ┤0   ├
#      │  Q │
# q_1: ┤1   ├
#      └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#        ┌────┐┌────┐
# q47_0: ┤0   ├┤0   ├
#        │  R ││  F │
# q47_1: ┤1   ├┤1   ├
#        └────┘└────┘
#
# Distribution Generator 'R' =
#        ┌───┐
# q48_0: ┤ H ├
#        └───┘
# q48_1: ─────
#
#
# Function Generator 'F' =
#
# q49_0: ──■──
#        ┌─┴─┐
# q49_1: ┤ X ├
#        └───┘
#
# Inverse QFT Circuit =
#        ┌───┐                         ░                   ░       ░
# q22_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#        └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q22_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#             └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q22_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                         └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Hamiltonian Simulation

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
#

# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 50, 0.284
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 44, 0.303, 54.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.018, 40.655, 40.62 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.415, 0.405
#
# ... execution complete at Aug 24, 2023 23:33:03 UTC in 255.353 secs
#
# Sample Circuit:
#        ┌───┐ ░ ┌───────────────┐ ┌──────────────┐ ░ ┌─────────────┐»
# q66_0: ┤ X ├─░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─┤0            ├»
#        └───┘ ░ ├───────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q66_1: ──────░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─┤1            ├»
#        ┌───┐ ░ └┬──────────────┤└┬──────────────┤ ░ ├─────────────┤»
# q66_2: ┤ X ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─┤0            ├»
#        └───┘ ░  ├──────────────┤ ├──────────────┤ ░ │  xxyyzz_opt │»
# q66_3: ──────░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─┤1            ├»
#        ┌───┐ ░  ├──────────────┤ ├──────────────┤ ░ ├─────────────┤»
# q66_4: ┤ X ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─┤0            ├»
#        └───┘ ░  ├──────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q66_5: ──────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─┤1            ├»
#              ░  └──────────────┘└───────────────┘ ░ └─────────────┘»
#  c4: 6/════════════════════════════════════════════════════════════»
#                                                                    »
# «                       ░ ┌───────────────┐ ┌──────────────┐ ░ ┌─────────────┐»
# «q66_0: ────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─┤0            ├»
# «       ┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# «q66_1: ┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─┤1            ├»
# «       │  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤ ░ ├─────────────┤»
# «q66_2: ┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─┤0            ├»
# «       ├─────────────┤ ░  ├──────────────┤ ├──────────────┤ ░ │  xxyyzz_opt │»
# «q66_3: ┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─┤1            ├»
# «       │  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤ ░ ├─────────────┤»
# «q66_4: ┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─┤0            ├»
# «       └─────────────┘ ░  ├──────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# «q66_5: ────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─┤1            ├»
# «                       ░  └──────────────┘└───────────────┘ ░ └─────────────┘»
# « c4: 6/══════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                       ░ ┌───────────────┐ ┌──────────────┐ ░ ┌─────────────┐»
# «q66_0: ────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─┤0            ├»
# «       ┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# «q66_1: ┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─┤1            ├»
# «       │  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤ ░ ├─────────────┤»
# «q66_2: ┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─┤0            ├»
# «       ├─────────────┤ ░  ├──────────────┤ ├──────────────┤ ░ │  xxyyzz_opt │»
# «q66_3: ┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─┤1            ├»
# «       │  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤ ░ ├─────────────┤»
# «q66_4: ┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─┤0            ├»
# «       └─────────────┘ ░  ├──────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# «q66_5: ────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─┤1            ├»
# «                       ░  └──────────────┘└───────────────┘ ░ └─────────────┘»
# « c4: 6/══════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                       ░ ┌─┐
# «q66_0: ────────────────░─┤M├───────────────
# «       ┌─────────────┐ ░ └╥┘┌─┐
# «q66_1: ┤0            ├─░──╫─┤M├────────────
# «       │  xxyyzz_opt │ ░  ║ └╥┘┌─┐
# «q66_2: ┤1            ├─░──╫──╫─┤M├─────────
# «       ├─────────────┤ ░  ║  ║ └╥┘┌─┐
# «q66_3: ┤0            ├─░──╫──╫──╫─┤M├──────
# «       │  xxyyzz_opt │ ░  ║  ║  ║ └╥┘┌─┐
# «q66_4: ┤1            ├─░──╫──╫──╫──╫─┤M├───
# «       └─────────────┘ ░  ║  ║  ║  ║ └╥┘┌─┐
# «q66_5: ────────────────░──╫──╫──╫──╫──╫─┤M├
# «                       ░  ║  ║  ║  ║  ║ └╥┘
# « c4: 6/═══════════════════╩══╩══╩══╩══╩══╩═
# «                          0  1  2  3  4  5
#
# XXYYZZ_opt =
#                       ┌───┐┌─────────────┐                    ┌───┐»
# q108_0: ──────────────┤ X ├┤ Rz(-1.5603) ├──■─────────────────┤ X ├»
#         ┌────────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘»
# q108_1: ┤ Rz(1.5708) ├──■───┤ Ry(1.5603) ├┤ X ├┤ Ry(-1.5603) ├──■──»
#         └────────────┘      └────────────┘└───┘└─────────────┘     »
# «        ┌─────────────┐
# «q108_0: ┤ Rz(-1.5708) ├
# «        └─────────────┘
# «q108_1: ───────────────
# «

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
#

# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 10, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 341, 0.63, 272.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.018, 75.021, 74.863 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.044, 0.0
#
# ... execution complete at Aug 24, 2023 23:36:04 UTC in 114.55 secs
#
# Sample Circuit:
#         ┌─────┐┌────────────────────┐┌────────────────────┐»
#   q0_0: ┤0    ├┤0                   ├┤0                   ├»
#         │     ││                    ││                    │»
#   q0_1: ┤1    ├┤1                   ├┤1                   ├»
#         │  Hf ││  Cluster Op (0, 1) ││  Cluster Op (2, 3) │»
#   q0_2: ┤2    ├┤2                   ├┤2                   ├»
#         │     ││                    ││                    │»
#   q0_3: ┤3    ├┤3                   ├┤3                   ├»
#         └─────┘└────────────────────┘└────────────────────┘»
# meas: 4/═══════════════════════════════════════════════════»
#                                                            »
# «        ┌──────────────────────────┐ ░ ┌─┐
# «  q0_0: ┤0                         ├─░─┤M├─────────
# «        │                          │ ░ └╥┘┌─┐
# «  q0_1: ┤1                         ├─░──╫─┤M├──────
# «        │  Cluster Op (0, 1, 2, 3) │ ░  ║ └╥┘┌─┐
# «  q0_2: ┤2                         ├─░──╫──╫─┤M├───
# «        │                          │ ░  ║  ║ └╥┘┌─┐
# «  q0_3: ┤3                         ├─░──╫──╫──╫─┤M├
# «        └──────────────────────────┘ ░  ║  ║  ║ └╥┘
# «meas: 4/════════════════════════════════╩══╩══╩══╩═
# «                                        0  1  2  3
#
# Hartree Fock Generator 'Hf' =
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#
#
# Cluster Operator Example 'Cluster Op' =
#      ┌──────────────────────────────────────────────────────────────────────┐
# q_0: ┤0                                                                     ├
#      │                                                                      │
# q_1: ┤1                                                                     ├
#      │  exp(-it (YXXX + XYXX + XXYX + YYYX + XXXY + YYXY + YXYY + XYYY))(1) │
# q_2: ┤2                                                                     ├
#      │                                                                      │
# q_3: ┤3                                                                     ├
#      └──────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding Algorithm Benchmark - Qiskit
# ... using circuit method 1
# Max number of qubits 7 is too low to run method 1 of Shor's Order Finding

# %% [markdown]
# ### Shor - Method 2

# %%
# This benchmark is commented out because conditional operations aren't supported in Fire Opal as of September 2023.

# import sys
# sys.path.insert(1, "shors/qiskit")
# import shors_benchmark
# shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
#                 method=2,
#                 backend_id=backend_id, provider_backend=provider_backend,
#                 hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)
# Out:
# ****** NO RESULTS for Shor's Order Finding (2) ******
